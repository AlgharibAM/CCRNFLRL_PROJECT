# %% [markdown]
# # Deep Q learning with Doom 🕹️
# In this notebook we'll implement an agent <b>that plays Doom by using a Deep Q learning architecture.</b> <br>
# Our agent playing Doom:
#
#
#
# <img src="assets/doom.gif" style="max-width: 600px;" alt="Deep Q learning with Doom"/>

# %% [markdown]
# ## For Google Collab

# %%
# %%bash
# # Install deps from
# # https://github.com/mwydmuch/ViZDoom/blob/master/doc/Building.md#-linux
#
# apt-get install build-essential zlib1g-dev libsdl2-dev libjpeg-dev \
# nasm tar libbz2-dev libgtk2.0-dev cmake git libfluidsynth-dev libgme-dev \
# libopenal-dev timidity libwildmidi-dev unzip
#
# # Boost libraries
# apt-get install libboost-all-dev
#
# # Lua binding dependencies
# apt-get install liblua5.1-dev
# Out:
# Couldn't find program: 'bash'

# %% [markdown]
# ## Install vizdoom, tensorflow and scikit-image

# %%
# %pip install vizdoom
# %pip install tensorflow
# %pip install scikit-image
# %pip install matplotlib
# Out:
# Collecting vizdoom
#   Downloading vizdoom-1.2.0-cp311-cp311-win_amd64.whl (15.5 MB)
#                                               0.0/15.5 MB ? eta -:--:--
#                                               0.1/15.5 MB 7.0 MB/s eta 0:00:03
#                                               0.1/15.5 MB 7.0 MB/s eta 0:00:03
#                                               0.2/15.5 MB 1.7 MB/s eta 0:00:10
#                                               0.3/15.5 MB 1.4 MB/s eta 0:00:11
#      -                                        0.4/15.5 MB 1.9 MB/s eta 0:00:09
#      -                                        0.5/15.5 MB 1.9 MB/s eta 0:00:08
#      -                                        0.7/15.5 MB 2.2 MB/s eta 0:00:07
#      --                                       0.9/15.5 MB 2.6 MB/s eta 0:00:06
#      --                                       1.0/15.5 MB 2.8 MB/s eta 0:00:06
#      --                                       1.0/15.5 MB 2.8 MB/s eta 0:00:06
#      --                                       1.0/15.5 MB 2.8 MB/s eta 0:00:06
#      --                                       1.2/15.5 MB 2.2 MB/s eta 0:00:07
#      ---                                      1.3/15.5 MB 2.4 MB/s eta 0:00:06
#      ----                                     1.6/15.5 MB 2.6 MB/s eta 0:00:06
#      ----                                     1.7/15.5 MB 2.7 MB/s eta 0:00:06
#      -----                                    1.9/15.5 MB 2.8 MB/s eta 0:00:05
#      -----                                    2.1/15.5 MB 2.9 MB/s eta 0:00:05
#      -----                                    2.3/15.5 MB 2.9 MB/s eta 0:00:05
#      ------                                   2.5/15.5 MB 3.0 MB/s eta 0:00:05
#      ------                                   2.7/15.5 MB 3.1 MB/s eta 0:00:05
#      -------                                  2.9/15.5 MB 3.1 MB/s eta 0:00:05
#      --------                                 3.2/15.5 MB 3.2 MB/s eta 0:00:04
#      ---------                                3.5/15.5 MB 3.4 MB/s eta 0:00:04
#      ---------                                3.7/15.5 MB 3.4 MB/s eta 0:00:04
#      ----------                               3.9/15.5 MB 3.5 MB/s eta 0:00:04
#      ----------                               4.1/15.5 MB 3.5 MB/s eta 0:00:04
#      ----------                               4.2/15.5 MB 3.5 MB/s eta 0:00:04
#      -----------                              4.3/15.5 MB 3.5 MB/s eta 0:00:04
#      -----------                              4.5/15.5 MB 3.5 MB/s eta 0:00:04
#      ------------                             4.7/15.5 MB 3.5 MB/s eta 0:00:04
#      ------------                             4.9/15.5 MB 3.5 MB/s eta 0:00:04
#      ------------                             5.0/15.5 MB 3.4 MB/s eta 0:00:04
#      ------------                             5.0/15.5 MB 3.4 MB/s eta 0:00:04
#      ------------                             5.0/15.5 MB 3.4 MB/s eta 0:00:04
#      ------------                             5.0/15.5 MB 3.4 MB/s eta 0:00:04
#      ------------                             5.0/15.5 MB 3.4 MB/s eta 0:00:04
#      ------------                             5.0/15.5 MB 3.4 MB/s eta 0:00:04
#      ------------                             5.0/15.5 MB 3.4 MB/s eta 0:00:04
#      ------------                             5.0/15.5 MB 3.4 MB/s eta 0:00:04
#      -------------                            5.2/15.5 MB 2.9 MB/s eta 0:00:04
#      ----------------                         6.3/15.5 MB 3.4 MB/s eta 0:00:03
#      ----------------                         6.3/15.5 MB 3.3 MB/s eta 0:00:03
#      ----------------                         6.3/15.5 MB 3.3 MB/s eta 0:00:03
#      ----------------                         6.3/15.5 MB 3.3 MB/s eta 0:00:03
#      ----------------                         6.3/15.5 MB 3.3 MB/s eta 0:00:03
#      ----------------                         6.3/15.5 MB 3.3 MB/s eta 0:00:03
#      ----------------                         6.3/15.5 MB 3.3 MB/s eta 0:00:03
#      ----------------                         6.3/15.5 MB 3.3 MB/s eta 0:00:03
#      ----------------                         6.3/15.5 MB 3.3 MB/s eta 0:00:03
#      ----------------                         6.5/15.5 MB 2.8 MB/s eta 0:00:04
#      -----------------                        6.7/15.5 MB 2.8 MB/s eta 0:00:04
#      -----------------                        6.9/15.5 MB 2.9 MB/s eta 0:00:04
#      ------------------                       7.0/15.5 MB 2.8 MB/s eta 0:00:03
#      ------------------                       7.3/15.5 MB 2.9 MB/s eta 0:00:03
#      -------------------                      7.4/15.5 MB 2.9 MB/s eta 0:00:03
#      --------------------                     7.7/15.5 MB 2.9 MB/s eta 0:00:03
#      --------------------                     7.9/15.5 MB 3.0 MB/s eta 0:00:03
#      ---------------------                    8.2/15.5 MB 3.0 MB/s eta 0:00:03
#      ---------------------                    8.4/15.5 MB 3.0 MB/s eta 0:00:03
#      ---------------------                    8.4/15.5 MB 3.0 MB/s eta 0:00:03
#      ---------------------                    8.4/15.5 MB 3.0 MB/s eta 0:00:03
#      ---------------------                    8.4/15.5 MB 3.0 MB/s eta 0:00:03
#      ---------------------                    8.4/15.5 MB 3.0 MB/s eta 0:00:03
#      ----------------------                   8.5/15.5 MB 2.8 MB/s eta 0:00:03
#      ----------------------                   8.7/15.5 MB 2.8 MB/s eta 0:00:03
#      -----------------------                  9.0/15.5 MB 2.9 MB/s eta 0:00:03
#      -----------------------                  9.2/15.5 MB 2.9 MB/s eta 0:00:03
#      ------------------------                 9.4/15.5 MB 3.0 MB/s eta 0:00:03
#      ------------------------                 9.4/15.5 MB 3.0 MB/s eta 0:00:03
#      ------------------------                 9.4/15.5 MB 3.0 MB/s eta 0:00:03
#      ------------------------                 9.4/15.5 MB 3.0 MB/s eta 0:00:03
#      ------------------------                 9.4/15.5 MB 3.0 MB/s eta 0:00:03
#      ------------------------                 9.4/15.5 MB 3.0 MB/s eta 0:00:03
#      ------------------------                 9.5/15.5 MB 2.8 MB/s eta 0:00:03
#      -------------------------                9.8/15.5 MB 2.8 MB/s eta 0:00:03
#      --------------------------               10.1/15.5 MB 2.8 MB/s eta 0:00:02
#      --------------------------               10.4/15.5 MB 2.9 MB/s eta 0:00:02
#      ---------------------------              10.5/15.5 MB 2.9 MB/s eta 0:00:02
#      ---------------------------              10.5/15.5 MB 2.9 MB/s eta 0:00:02
#      ---------------------------              10.5/15.5 MB 2.9 MB/s eta 0:00:02
#      ---------------------------              10.5/15.5 MB 2.9 MB/s eta 0:00:02
#      ---------------------------              10.8/15.5 MB 2.8 MB/s eta 0:00:02
#      ----------------------------             10.9/15.5 MB 2.8 MB/s eta 0:00:02
#      -----------------------------            11.3/15.5 MB 2.8 MB/s eta 0:00:02
#      -----------------------------            11.5/15.5 MB 2.9 MB/s eta 0:00:02
#      -----------------------------            11.5/15.5 MB 2.9 MB/s eta 0:00:02
#      -----------------------------            11.5/15.5 MB 2.9 MB/s eta 0:00:02
#      -----------------------------            11.5/15.5 MB 2.9 MB/s eta 0:00:02
#      -----------------------------            11.5/15.5 MB 2.9 MB/s eta 0:00:02
#      -----------------------------            11.5/15.5 MB 2.9 MB/s eta 0:00:02
#      -----------------------------            11.5/15.5 MB 2.9 MB/s eta 0:00:02
#      ------------------------------           11.8/15.5 MB 2.7 MB/s eta 0:00:02
#      -------------------------------          12.0/15.5 MB 2.7 MB/s eta 0:00:02
#      -------------------------------          12.3/15.5 MB 2.7 MB/s eta 0:00:02
#      --------------------------------         12.5/15.5 MB 2.7 MB/s eta 0:00:02
#      --------------------------------         12.6/15.5 MB 2.7 MB/s eta 0:00:02
#      --------------------------------         12.7/15.5 MB 2.7 MB/s eta 0:00:02
#      ---------------------------------        12.9/15.5 MB 2.7 MB/s eta 0:00:01
#      ---------------------------------        13.1/15.5 MB 2.7 MB/s eta 0:00:01
#      ----------------------------------       13.3/15.5 MB 2.7 MB/s eta 0:00:01
#      -----------------------------------      13.6/15.5 MB 2.7 MB/s eta 0:00:01
#      ------------------------------------     14.0/15.5 MB 2.7 MB/s eta 0:00:01
#      ------------------------------------     14.3/15.5 MB 2.7 MB/s eta 0:00:01
#      -------------------------------------    14.5/15.5 MB 2.7 MB/s eta 0:00:01
#      -------------------------------------    14.6/15.5 MB 2.7 MB/s eta 0:00:01
#      --------------------------------------   14.9/15.5 MB 2.7 MB/s eta 0:00:01
#      ---------------------------------------  15.1/15.5 MB 2.7 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------  15.5/15.5 MB 3.0 MB/s eta 0:00:01
#      ---------------------------------------- 15.5/15.5 MB 1.6 MB/s eta 0:00:00
# Collecting numpy (from vizdoom)
#   Downloading numpy-1.25.0-cp311-cp311-win_amd64.whl (15.0 MB)
#                                               0.0/15.0 MB ? eta -:--:--
#                                               0.1/15.0 MB 3.2 MB/s eta 0:00:05
#                                               0.2/15.0 MB 2.5 MB/s eta 0:00:07
#                                               0.3/15.0 MB 2.4 MB/s eta 0:00:07
#      -                                        0.5/15.0 MB 2.7 MB/s eta 0:00:06
#      --                                       0.8/15.0 MB 3.5 MB/s eta 0:00:05
#      --                                       1.0/15.0 MB 3.9 MB/s eta 0:00:04
#      ---                                      1.3/15.0 MB 4.0 MB/s eta 0:00:04
#      ---                                      1.5/15.0 MB 4.3 MB/s eta 0:00:04
#      ----                                     1.7/15.0 MB 4.3 MB/s eta 0:00:04
#      -----                                    2.0/15.0 MB 4.5 MB/s eta 0:00:03
#      -----                                    2.1/15.0 MB 4.4 MB/s eta 0:00:03
#      ------                                   2.4/15.0 MB 4.6 MB/s eta 0:00:03
#      -------                                  2.7/15.0 MB 4.7 MB/s eta 0:00:03
#      --------                                 3.0/15.0 MB 4.7 MB/s eta 0:00:03
#      --------                                 3.4/15.0 MB 4.9 MB/s eta 0:00:03
#      ---------                                3.6/15.0 MB 4.9 MB/s eta 0:00:03
#      ----------                               3.9/15.0 MB 5.0 MB/s eta 0:00:03
#      -----------                              4.2/15.0 MB 5.0 MB/s eta 0:00:03
#      -----------                              4.5/15.0 MB 5.1 MB/s eta 0:00:03
#      ------------                             4.7/15.0 MB 5.2 MB/s eta 0:00:03
#      -------------                            4.9/15.0 MB 5.2 MB/s eta 0:00:02
#      -------------                            5.0/15.0 MB 4.9 MB/s eta 0:00:03
#      --------------                           5.3/15.0 MB 5.1 MB/s eta 0:00:02
#      --------------                           5.6/15.0 MB 5.1 MB/s eta 0:00:02
#      ---------------                          5.9/15.0 MB 5.1 MB/s eta 0:00:02
#      ----------------                         6.1/15.0 MB 5.2 MB/s eta 0:00:02
#      ----------------                         6.4/15.0 MB 5.1 MB/s eta 0:00:02
#      -----------------                        6.7/15.0 MB 5.2 MB/s eta 0:00:02
#      ------------------                       6.9/15.0 MB 5.3 MB/s eta 0:00:02
#      -------------------                      7.3/15.0 MB 5.3 MB/s eta 0:00:02
#      --------------------                     7.6/15.0 MB 5.3 MB/s eta 0:00:02
#      --------------------                     7.9/15.0 MB 5.3 MB/s eta 0:00:02
#      ---------------------                    8.2/15.0 MB 5.3 MB/s eta 0:00:02
#      ----------------------                   8.4/15.0 MB 5.4 MB/s eta 0:00:02
#      ----------------------                   8.6/15.0 MB 5.4 MB/s eta 0:00:02
#      -----------------------                  8.9/15.0 MB 5.4 MB/s eta 0:00:02
#      ------------------------                 9.2/15.0 MB 5.4 MB/s eta 0:00:02
#      -------------------------                9.4/15.0 MB 5.4 MB/s eta 0:00:02
#      -------------------------                9.7/15.0 MB 5.4 MB/s eta 0:00:01
#      --------------------------               9.9/15.0 MB 5.4 MB/s eta 0:00:01
#      ---------------------------              10.2/15.0 MB 5.4 MB/s eta 0:00:01
#      ---------------------------              10.5/15.0 MB 5.6 MB/s eta 0:00:01
#      ----------------------------             10.8/15.0 MB 5.7 MB/s eta 0:00:01
#      -----------------------------            11.0/15.0 MB 5.7 MB/s eta 0:00:01
#      -----------------------------            11.3/15.0 MB 5.7 MB/s eta 0:00:01
#      ------------------------------           11.5/15.0 MB 5.7 MB/s eta 0:00:01
#      -------------------------------          11.7/15.0 MB 5.7 MB/s eta 0:00:01
#      --------------------------------         12.0/15.0 MB 5.7 MB/s eta 0:00:01
#      --------------------------------         12.3/15.0 MB 5.8 MB/s eta 0:00:01
#      ---------------------------------        12.6/15.0 MB 5.8 MB/s eta 0:00:01
#      ----------------------------------       12.9/15.0 MB 5.8 MB/s eta 0:00:01
#      -----------------------------------      13.2/15.0 MB 5.8 MB/s eta 0:00:01
#      -----------------------------------      13.4/15.0 MB 5.8 MB/s eta 0:00:01
#      ------------------------------------     13.8/15.0 MB 5.8 MB/s eta 0:00:01
#      -------------------------------------    14.0/15.0 MB 5.8 MB/s eta 0:00:01
#      -------------------------------------    14.2/15.0 MB 5.8 MB/s eta 0:00:01
#      --------------------------------------   14.6/15.0 MB 5.8 MB/s eta 0:00:01
#      ---------------------------------------  14.9/15.0 MB 5.8 MB/s eta 0:00:01
#      ---------------------------------------  15.0/15.0 MB 5.8 MB/s eta 0:00:01
#      ---------------------------------------  15.0/15.0 MB 5.8 MB/s eta 0:00:01
#      ---------------------------------------  15.0/15.0 MB 5.8 MB/s eta 0:00:01
#      ---------------------------------------  15.0/15.0 MB 5.8 MB/s eta 0:00:01
#      ---------------------------------------  15.0/15.0 MB 5.8 MB/s eta 0:00:01
#      ---------------------------------------  15.0/15.0 MB 5.8 MB/s eta 0:00:01
#      ---------------------------------------  15.0/15.0 MB 5.8 MB/s eta 0:00:01
#      ---------------------------------------  15.0/15.0 MB 5.8 MB/s eta 0:00:01
#      ---------------------------------------  15.0/15.0 MB 5.8 MB/s eta 0:00:01
#      ---------------------------------------  15.0/15.0 MB 5.8 MB/s eta 0:00:01
#      ---------------------------------------  15.0/15.0 MB 5.8 MB/s eta 0:00:01
#      ---------------------------------------  15.0/15.0 MB 5.8 MB/s eta 0:00:01
#      ---------------------------------------  15.0/15.0 MB 5.8 MB/s eta 0:00:01
#      ---------------------------------------- 15.0/15.0 MB 4.1 MB/s eta 0:00:00
# Collecting gymnasium>=0.28.0 (from vizdoom)
#   Downloading gymnasium-0.28.1-py3-none-any.whl (925 kB)
#                                               0.0/925.5 kB ? eta -:--:--
#      ---------------                        389.1/925.5 kB 8.1 MB/s eta 0:00:01
#      -----------------------------          716.8/925.5 kB 6.5 MB/s eta 0:00:01
#      ------------------------------------   880.6/925.5 kB 5.6 MB/s eta 0:00:01
#      -------------------------------------  921.6/925.5 kB 5.3 MB/s eta 0:00:01
#      -------------------------------------  921.6/925.5 kB 5.3 MB/s eta 0:00:01
#      -------------------------------------  921.6/925.5 kB 5.3 MB/s eta 0:00:01
#      -------------------------------------  921.6/925.5 kB 5.3 MB/s eta 0:00:01
#      -------------------------------------  921.6/925.5 kB 5.3 MB/s eta 0:00:01
#      -------------------------------------- 925.5/925.5 kB 2.0 MB/s eta 0:00:00
# Collecting pygame>=2.1.3 (from vizdoom)
#   Downloading pygame-2.4.0-cp311-cp311-win_amd64.whl (10.6 MB)
#                                               0.0/10.6 MB ? eta -:--:--
#                                               0.1/10.6 MB 4.3 MB/s eta 0:00:03
#      -                                        0.3/10.6 MB 4.2 MB/s eta 0:00:03
#      -                                        0.5/10.6 MB 3.5 MB/s eta 0:00:03
#      --                                       0.6/10.6 MB 3.4 MB/s eta 0:00:03
#      ---                                      0.9/10.6 MB 3.6 MB/s eta 0:00:03
#      ----                                     1.2/10.6 MB 4.2 MB/s eta 0:00:03
#      -----                                    1.4/10.6 MB 4.4 MB/s eta 0:00:03
#      -------                                  1.9/10.6 MB 4.7 MB/s eta 0:00:02
#      --------                                 2.2/10.6 MB 4.9 MB/s eta 0:00:02
#      ---------                                2.5/10.6 MB 5.0 MB/s eta 0:00:02
#      ----------                               2.7/10.6 MB 5.1 MB/s eta 0:00:02
#      ----------                               2.8/10.6 MB 5.0 MB/s eta 0:00:02
#      ----------                               2.9/10.6 MB 4.6 MB/s eta 0:00:02
#      -----------                              3.0/10.6 MB 4.4 MB/s eta 0:00:02
#      -----------                              3.1/10.6 MB 4.3 MB/s eta 0:00:02
#      -----------                              3.1/10.6 MB 4.2 MB/s eta 0:00:02
#      -----------                              3.1/10.6 MB 4.2 MB/s eta 0:00:02
#      -----------                              3.1/10.6 MB 4.2 MB/s eta 0:00:02
#      -----------                              3.1/10.6 MB 4.2 MB/s eta 0:00:02
#      -----------                              3.1/10.6 MB 4.2 MB/s eta 0:00:02
#      -----------                              3.1/10.6 MB 4.2 MB/s eta 0:00:02
#      -----------                              3.1/10.6 MB 4.2 MB/s eta 0:00:02
#      -------------                            3.7/10.6 MB 3.2 MB/s eta 0:00:03
#      ----------------                         4.3/10.6 MB 3.7 MB/s eta 0:00:02
#      ----------------                         4.3/10.6 MB 3.7 MB/s eta 0:00:02
#      ----------------                         4.3/10.6 MB 3.7 MB/s eta 0:00:02
#      ----------------                         4.3/10.6 MB 3.7 MB/s eta 0:00:02
#      ----------------                         4.3/10.6 MB 3.7 MB/s eta 0:00:02
#      ------------------                       4.9/10.6 MB 3.5 MB/s eta 0:00:02
#      ------------------                       4.9/10.6 MB 3.4 MB/s eta 0:00:02
#      ------------------                       4.9/10.6 MB 3.4 MB/s eta 0:00:02
#      ------------------                       4.9/10.6 MB 3.2 MB/s eta 0:00:02
#      ------------------                       5.0/10.6 MB 3.2 MB/s eta 0:00:02
#      ------------------                       5.0/10.6 MB 3.2 MB/s eta 0:00:02
#      ------------------                       5.0/10.6 MB 3.2 MB/s eta 0:00:02
#      ---------------------                    5.6/10.6 MB 3.2 MB/s eta 0:00:02
#      ---------------------                    5.7/10.6 MB 3.2 MB/s eta 0:00:02
#      ----------------------                   6.0/10.6 MB 3.2 MB/s eta 0:00:02
#      -----------------------                  6.2/10.6 MB 3.2 MB/s eta 0:00:02
#      ------------------------                 6.4/10.6 MB 3.2 MB/s eta 0:00:02
#      ------------------------                 6.6/10.6 MB 3.2 MB/s eta 0:00:02
#      -------------------------                6.8/10.6 MB 3.3 MB/s eta 0:00:02
#      --------------------------               6.9/10.6 MB 3.3 MB/s eta 0:00:02
#      --------------------------               7.0/10.6 MB 3.2 MB/s eta 0:00:02
#      ---------------------------              7.3/10.6 MB 3.2 MB/s eta 0:00:02
#      ----------------------------             7.4/10.6 MB 3.2 MB/s eta 0:00:01
#      ----------------------------             7.7/10.6 MB 3.2 MB/s eta 0:00:01
#      -----------------------------            7.9/10.6 MB 3.3 MB/s eta 0:00:01
#      ------------------------------           8.1/10.6 MB 3.3 MB/s eta 0:00:01
#      -------------------------------          8.3/10.6 MB 3.3 MB/s eta 0:00:01
#      -------------------------------          8.3/10.6 MB 3.3 MB/s eta 0:00:01
#      -------------------------------          8.3/10.6 MB 3.2 MB/s eta 0:00:01
#      -------------------------------          8.4/10.6 MB 3.2 MB/s eta 0:00:01
#      -------------------------------          8.4/10.6 MB 3.2 MB/s eta 0:00:01
#      --------------------------------         8.5/10.6 MB 3.1 MB/s eta 0:00:01
#      --------------------------------         8.6/10.6 MB 3.1 MB/s eta 0:00:01
#      --------------------------------         8.6/10.6 MB 3.1 MB/s eta 0:00:01
#      --------------------------------         8.6/10.6 MB 3.1 MB/s eta 0:00:01
#      --------------------------------         8.6/10.6 MB 3.1 MB/s eta 0:00:01
#      ----------------------------------       9.0/10.6 MB 3.0 MB/s eta 0:00:01
#      ----------------------------------       9.0/10.6 MB 3.0 MB/s eta 0:00:01
#      ----------------------------------       9.1/10.6 MB 3.0 MB/s eta 0:00:01
#      -----------------------------------      9.3/10.6 MB 3.0 MB/s eta 0:00:01
#      -----------------------------------      9.4/10.6 MB 3.0 MB/s eta 0:00:01
#      ------------------------------------     9.5/10.6 MB 2.9 MB/s eta 0:00:01
#      ------------------------------------     9.6/10.6 MB 2.9 MB/s eta 0:00:01
#      -------------------------------------    9.9/10.6 MB 2.9 MB/s eta 0:00:01
#      -------------------------------------    10.0/10.6 MB 2.9 MB/s eta 0:00:01
#      --------------------------------------   10.1/10.6 MB 2.9 MB/s eta 0:00:01
#      --------------------------------------   10.2/10.6 MB 2.9 MB/s eta 0:00:01
#      --------------------------------------   10.3/10.6 MB 2.9 MB/s eta 0:00:01
#      ---------------------------------------  10.3/10.6 MB 2.9 MB/s eta 0:00:01
#      ---------------------------------------  10.5/10.6 MB 2.9 MB/s eta 0:00:01
#      ---------------------------------------  10.6/10.6 MB 2.9 MB/s eta 0:00:01
#      ---------------------------------------  10.6/10.6 MB 2.9 MB/s eta 0:00:01
#      ---------------------------------------  10.6/10.6 MB 2.9 MB/s eta 0:00:01
#      ---------------------------------------  10.6/10.6 MB 2.9 MB/s eta 0:00:01
#      ---------------------------------------  10.6/10.6 MB 2.9 MB/s eta 0:00:01
#      ---------------------------------------  10.6/10.6 MB 2.9 MB/s eta 0:00:01
#      ---------------------------------------  10.6/10.6 MB 2.9 MB/s eta 0:00:01
#      ---------------------------------------  10.6/10.6 MB 2.9 MB/s eta 0:00:01
#      ---------------------------------------  10.6/10.6 MB 2.9 MB/s eta 0:00:01
#      ---------------------------------------  10.6/10.6 MB 2.9 MB/s eta 0:00:01
#      ---------------------------------------  10.6/10.6 MB 2.9 MB/s eta 0:00:01
#      ---------------------------------------  10.6/10.6 MB 2.9 MB/s eta 0:00:01
#      ---------------------------------------  10.6/10.6 MB 2.9 MB/s eta 0:00:01
#      ---------------------------------------  10.6/10.6 MB 2.9 MB/s eta 0:00:01
#      ---------------------------------------  10.6/10.6 MB 2.9 MB/s eta 0:00:01
#      ---------------------------------------  10.6/10.6 MB 2.9 MB/s eta 0:00:01
#      ---------------------------------------  10.6/10.6 MB 2.9 MB/s eta 0:00:01
#      ---------------------------------------  10.6/10.6 MB 2.9 MB/s eta 0:00:01
#      ---------------------------------------  10.6/10.6 MB 2.9 MB/s eta 0:00:01
#      ---------------------------------------  10.6/10.6 MB 2.9 MB/s eta 0:00:01
#      ---------------------------------------  10.6/10.6 MB 2.9 MB/s eta 0:00:01
#      ---------------------------------------  10.6/10.6 MB 2.9 MB/s eta 0:00:01
#      ---------------------------------------  10.6/10.6 MB 2.9 MB/s eta 0:00:01
#      ---------------------------------------  10.6/10.6 MB 2.9 MB/s eta 0:00:01
#      ---------------------------------------  10.6/10.6 MB 2.9 MB/s eta 0:00:01
#      ---------------------------------------  10.6/10.6 MB 2.9 MB/s eta 0:00:01
#      ---------------------------------------  10.6/10.6 MB 2.9 MB/s eta 0:00:01
#      ---------------------------------------  10.6/10.6 MB 2.9 MB/s eta 0:00:01
#      ---------------------------------------  10.6/10.6 MB 2.9 MB/s eta 0:00:01
#      ---------------------------------------- 10.6/10.6 MB 2.0 MB/s eta 0:00:00
# Collecting jax-jumpy>=1.0.0 (from gymnasium>=0.28.0->vizdoom)
#   Downloading jax_jumpy-1.0.0-py3-none-any.whl (20 kB)
# Collecting cloudpickle>=1.2.0 (from gymnasium>=0.28.0->vizdoom)
#   Downloading cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# Collecting typing-extensions>=4.3.0 (from gymnasium>=0.28.0->vizdoom)
#   Downloading typing_extensions-4.6.3-py3-none-any.whl (31 kB)
# Collecting farama-notifications>=0.0.1 (from gymnasium>=0.28.0->vizdoom)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Installing collected packages: farama-notifications, typing-extensions, pygame, numpy, cloudpickle, jax-jumpy, gymnasium, vizdoom
# Successfully installed cloudpickle-2.2.1 farama-notifications-0.0.4 gymnasium-0.28.1 jax-jumpy-1.0.0 numpy-1.25.0 pygame-2.4.0 typing-extensions-4.6.3 vizdoom-1.2.0
# Note: you may need to restart the kernel to use updated packages.
# Collecting tensorflow
#   Downloading tensorflow-2.12.0-cp311-cp311-win_amd64.whl (1.9 kB)
# Collecting tensorflow-intel==2.12.0 (from tensorflow)
#   Downloading tensorflow_intel-2.12.0-cp311-cp311-win_amd64.whl (272.9 MB)
#                                               0.0/272.9 MB ? eta -:--:--
#                                             0.0/272.9 MB 660.6 kB/s eta 0:06:54
#                                             0.1/272.9 MB 751.6 kB/s eta 0:06:03
#                                             0.1/272.9 MB 787.7 kB/s eta 0:05:47
#                                             0.2/272.9 MB 766.6 kB/s eta 0:05:56
#                                               0.3/272.9 MB 1.1 MB/s eta 0:04:00
#                                               0.4/272.9 MB 1.3 MB/s eta 0:03:34
#                                               0.6/272.9 MB 1.8 MB/s eta 0:02:28
#                                               0.8/272.9 MB 2.2 MB/s eta 0:02:06
#                                               1.0/272.9 MB 2.5 MB/s eta 0:01:50
#                                               1.3/272.9 MB 2.8 MB/s eta 0:01:36
#                                               1.6/272.9 MB 3.2 MB/s eta 0:01:26
#                                               1.7/272.9 MB 3.0 MB/s eta 0:01:32
#                                               1.9/272.9 MB 3.1 MB/s eta 0:01:28
#                                               2.2/272.9 MB 3.3 MB/s eta 0:01:23
#                                               2.4/272.9 MB 3.4 MB/s eta 0:01:20
#                                               2.4/272.9 MB 3.4 MB/s eta 0:01:20
#                                               3.0/272.9 MB 3.7 MB/s eta 0:01:13
#                                               3.2/272.9 MB 3.8 MB/s eta 0:01:11
#                                               3.4/272.9 MB 3.8 MB/s eta 0:01:11
#                                               3.7/272.9 MB 3.9 MB/s eta 0:01:09
#                                               4.0/272.9 MB 4.1 MB/s eta 0:01:06
#                                               4.4/272.9 MB 4.2 MB/s eta 0:01:04
#                                               4.7/272.9 MB 4.3 MB/s eta 0:01:04
#                                               5.0/272.9 MB 4.4 MB/s eta 0:01:02
#                                               5.2/272.9 MB 4.4 MB/s eta 0:01:01
#                                               5.5/272.9 MB 4.4 MB/s eta 0:01:01
#                                               5.8/272.9 MB 4.5 MB/s eta 0:01:00
#                                               5.9/272.9 MB 4.5 MB/s eta 0:00:59
#                                               6.2/272.9 MB 4.6 MB/s eta 0:00:59
#                                               6.5/272.9 MB 4.6 MB/s eta 0:00:58
#                                               6.6/272.9 MB 4.6 MB/s eta 0:00:59
#      -                                        6.8/272.9 MB 4.5 MB/s eta 0:00:59
#      -                                        7.1/272.9 MB 4.6 MB/s eta 0:00:58
#      -                                        7.4/272.9 MB 4.6 MB/s eta 0:00:58
#      -                                        7.6/272.9 MB 4.7 MB/s eta 0:00:57
#      -                                        7.9/272.9 MB 4.7 MB/s eta 0:00:57
#      -                                        8.1/272.9 MB 4.7 MB/s eta 0:00:57
#      -                                        8.4/272.9 MB 4.8 MB/s eta 0:00:56
#      -                                        8.7/272.9 MB 4.8 MB/s eta 0:00:55
#      -                                        9.1/272.9 MB 4.8 MB/s eta 0:00:55
#      -                                        9.3/272.9 MB 4.9 MB/s eta 0:00:54
#      -                                        9.6/272.9 MB 4.9 MB/s eta 0:00:54
#      -                                        9.9/272.9 MB 4.9 MB/s eta 0:00:54
#      -                                       10.2/272.9 MB 5.0 MB/s eta 0:00:53
#      -                                       10.5/272.9 MB 5.5 MB/s eta 0:00:48
#      -                                       10.8/272.9 MB 5.6 MB/s eta 0:00:47
#      -                                       11.0/272.9 MB 5.6 MB/s eta 0:00:47
#      -                                       11.3/272.9 MB 5.6 MB/s eta 0:00:47
#      -                                       11.6/272.9 MB 5.7 MB/s eta 0:00:46
#      -                                       11.9/272.9 MB 5.6 MB/s eta 0:00:47
#      -                                       12.3/272.9 MB 5.8 MB/s eta 0:00:45
#      -                                       12.5/272.9 MB 5.8 MB/s eta 0:00:45
#      -                                       12.8/272.9 MB 6.0 MB/s eta 0:00:44
#      -                                       13.1/272.9 MB 5.8 MB/s eta 0:00:45
#      -                                       13.4/272.9 MB 5.9 MB/s eta 0:00:45
#      -                                       13.7/272.9 MB 5.8 MB/s eta 0:00:45
#      -                                       14.0/272.9 MB 5.9 MB/s eta 0:00:44
#      --                                      14.2/272.9 MB 5.9 MB/s eta 0:00:44
#      --                                      14.4/272.9 MB 5.9 MB/s eta 0:00:44
#      --                                      14.7/272.9 MB 5.9 MB/s eta 0:00:44
#      --                                      14.9/272.9 MB 5.8 MB/s eta 0:00:45
#      --                                      15.2/272.9 MB 5.8 MB/s eta 0:00:45
#      --                                      15.4/272.9 MB 5.8 MB/s eta 0:00:45
#      --                                      15.7/272.9 MB 5.8 MB/s eta 0:00:44
#      --                                      16.1/272.9 MB 5.9 MB/s eta 0:00:44
#      --                                      16.4/272.9 MB 5.8 MB/s eta 0:00:44
#      --                                      16.7/272.9 MB 5.9 MB/s eta 0:00:44
#      --                                      17.0/272.9 MB 6.1 MB/s eta 0:00:43
#      --                                      17.3/272.9 MB 6.1 MB/s eta 0:00:43
#      --                                      17.5/272.9 MB 6.1 MB/s eta 0:00:43
#      --                                      17.7/272.9 MB 6.0 MB/s eta 0:00:43
#      --                                      18.0/272.9 MB 6.0 MB/s eta 0:00:43
#      --                                      18.1/272.9 MB 5.9 MB/s eta 0:00:44
#      --                                      18.4/272.9 MB 5.8 MB/s eta 0:00:44
#      --                                      18.6/272.9 MB 5.8 MB/s eta 0:00:44
#      --                                      18.8/272.9 MB 5.7 MB/s eta 0:00:45
#      --                                      18.8/272.9 MB 5.7 MB/s eta 0:00:45
#      --                                      18.8/272.9 MB 5.7 MB/s eta 0:00:45
#      --                                      18.8/272.9 MB 5.7 MB/s eta 0:00:45
#      --                                      18.8/272.9 MB 5.7 MB/s eta 0:00:45
#      --                                      18.8/272.9 MB 5.7 MB/s eta 0:00:45
#      --                                      18.8/272.9 MB 5.7 MB/s eta 0:00:45
#      --                                      18.8/272.9 MB 5.7 MB/s eta 0:00:45
#      --                                      18.8/272.9 MB 5.7 MB/s eta 0:00:45
#      --                                      20.2/272.9 MB 5.3 MB/s eta 0:00:48
#      --                                      20.9/272.9 MB 5.5 MB/s eta 0:00:46
#      --                                      20.9/272.9 MB 5.5 MB/s eta 0:00:46
#      --                                      20.9/272.9 MB 5.5 MB/s eta 0:00:46
#      --                                      20.9/272.9 MB 5.5 MB/s eta 0:00:46
#      ---                                     22.0/272.9 MB 5.5 MB/s eta 0:00:46
#      ---                                     22.1/272.9 MB 5.5 MB/s eta 0:00:46
#      ---                                     22.2/272.9 MB 5.4 MB/s eta 0:00:47
#      ---                                     22.5/272.9 MB 5.3 MB/s eta 0:00:48
#      ---                                     22.7/272.9 MB 5.2 MB/s eta 0:00:48
#      ---                                     23.0/272.9 MB 5.3 MB/s eta 0:00:48
#      ---                                     23.2/272.9 MB 5.2 MB/s eta 0:00:48
#      ---                                     23.4/272.9 MB 5.2 MB/s eta 0:00:48
#      ---                                     23.7/272.9 MB 5.2 MB/s eta 0:00:48
#      ---                                     23.8/272.9 MB 5.2 MB/s eta 0:00:49
#      ---                                     24.1/272.9 MB 5.2 MB/s eta 0:00:48
#      ---                                     24.3/272.9 MB 5.1 MB/s eta 0:00:49
#      ---                                     24.5/272.9 MB 5.2 MB/s eta 0:00:49
#      ---                                     24.8/272.9 MB 5.2 MB/s eta 0:00:49
#      ---                                     25.0/272.9 MB 5.1 MB/s eta 0:00:49
#      ---                                     25.3/272.9 MB 5.1 MB/s eta 0:00:49
#      ---                                     25.5/272.9 MB 5.1 MB/s eta 0:00:49
#      ---                                     25.7/272.9 MB 5.2 MB/s eta 0:00:48
#      ---                                     26.0/272.9 MB 5.1 MB/s eta 0:00:49
#      ---                                     26.2/272.9 MB 5.1 MB/s eta 0:00:49
#      ---                                     26.4/272.9 MB 5.1 MB/s eta 0:00:49
#      ---                                     26.7/272.9 MB 5.1 MB/s eta 0:00:49
#      ---                                     27.0/272.9 MB 5.1 MB/s eta 0:00:49
#      ---                                     27.1/272.9 MB 5.0 MB/s eta 0:00:49
#      ---                                     27.4/272.9 MB 5.0 MB/s eta 0:00:49
#      ---                                     27.7/272.9 MB 5.0 MB/s eta 0:00:49
#      ----                                    28.1/272.9 MB 5.1 MB/s eta 0:00:49
#      ----                                    28.2/272.9 MB 5.0 MB/s eta 0:00:49
#      ----                                    28.5/272.9 MB 5.1 MB/s eta 0:00:49
#      ----                                    28.6/272.9 MB 5.1 MB/s eta 0:00:49
#      ----                                    28.9/272.9 MB 5.1 MB/s eta 0:00:48
#      ----                                    29.1/272.9 MB 6.2 MB/s eta 0:00:40
#      ----                                    29.3/272.9 MB 6.1 MB/s eta 0:00:41
#      ----                                    29.6/272.9 MB 5.9 MB/s eta 0:00:42
#      ----                                    29.7/272.9 MB 5.7 MB/s eta 0:00:43
#      ----                                    29.9/272.9 MB 5.6 MB/s eta 0:00:44
#      ----                                    30.2/272.9 MB 5.4 MB/s eta 0:00:45
#      ----                                    30.4/272.9 MB 5.4 MB/s eta 0:00:46
#      ----                                    30.6/272.9 MB 5.2 MB/s eta 0:00:47
#      ----                                    30.9/272.9 MB 5.2 MB/s eta 0:00:47
#      ----                                    31.1/272.9 MB 5.1 MB/s eta 0:00:48
#      ----                                    31.3/272.9 MB 5.5 MB/s eta 0:00:45
#      ----                                    31.7/272.9 MB 5.3 MB/s eta 0:00:46
#      ----                                    32.0/272.9 MB 5.2 MB/s eta 0:00:47
#      ----                                    32.3/272.9 MB 5.1 MB/s eta 0:00:48
#      ----                                    32.7/272.9 MB 5.2 MB/s eta 0:00:46
#      ----                                    32.8/272.9 MB 5.2 MB/s eta 0:00:47
#      ----                                    33.0/272.9 MB 5.2 MB/s eta 0:00:46
#      ----                                    33.3/272.9 MB 5.2 MB/s eta 0:00:46
#      ----                                    33.5/272.9 MB 5.3 MB/s eta 0:00:46
#      ----                                    33.8/272.9 MB 5.3 MB/s eta 0:00:46
#      ----                                    34.1/272.9 MB 5.3 MB/s eta 0:00:45
#      ----                                    34.4/272.9 MB 5.4 MB/s eta 0:00:45
#      ----                                    34.7/272.9 MB 5.4 MB/s eta 0:00:45
#      ----                                    34.9/272.9 MB 5.4 MB/s eta 0:00:45
#      -----                                   35.2/272.9 MB 5.4 MB/s eta 0:00:45
#      -----                                   35.5/272.9 MB 5.4 MB/s eta 0:00:45
#      -----                                   35.7/272.9 MB 5.4 MB/s eta 0:00:45
#      -----                                   35.7/272.9 MB 5.3 MB/s eta 0:00:45
#      -----                                   36.0/272.9 MB 5.3 MB/s eta 0:00:45
#      -----                                   36.1/272.9 MB 5.2 MB/s eta 0:00:46
#      -----                                   36.4/272.9 MB 5.2 MB/s eta 0:00:46
#      -----                                   36.6/272.9 MB 5.2 MB/s eta 0:00:46
#      -----                                   36.9/272.9 MB 5.2 MB/s eta 0:00:46
#      -----                                   37.0/272.9 MB 5.2 MB/s eta 0:00:46
#      -----                                   37.3/272.9 MB 5.2 MB/s eta 0:00:46
#      -----                                   37.4/272.9 MB 5.2 MB/s eta 0:00:46
#      -----                                   37.5/272.9 MB 5.0 MB/s eta 0:00:47
#      -----                                   37.9/272.9 MB 5.0 MB/s eta 0:00:47
#      -----                                   38.2/272.9 MB 5.0 MB/s eta 0:00:47
#      -----                                   38.5/272.9 MB 5.1 MB/s eta 0:00:46
#      -----                                   38.8/272.9 MB 5.1 MB/s eta 0:00:46
#      -----                                   39.1/272.9 MB 5.2 MB/s eta 0:00:46
#      -----                                   39.3/272.9 MB 5.1 MB/s eta 0:00:46
#      -----                                   39.6/272.9 MB 5.2 MB/s eta 0:00:45
#      -----                                   39.8/272.9 MB 5.2 MB/s eta 0:00:46
#      -----                                   40.2/272.9 MB 5.3 MB/s eta 0:00:45
#      -----                                   40.6/272.9 MB 5.3 MB/s eta 0:00:45
#      -----                                   40.7/272.9 MB 5.2 MB/s eta 0:00:45
#      -----                                   41.0/272.9 MB 5.2 MB/s eta 0:00:45
#      -----                                   41.3/272.9 MB 5.2 MB/s eta 0:00:45
#      -----                                   41.6/272.9 MB 5.2 MB/s eta 0:00:45
#      -----                                   42.0/272.9 MB 5.2 MB/s eta 0:00:45
#      ------                                  42.3/272.9 MB 5.2 MB/s eta 0:00:45
#      ------                                  42.6/272.9 MB 5.3 MB/s eta 0:00:44
#      ------                                  42.9/272.9 MB 5.3 MB/s eta 0:00:44
#      ------                                  43.1/272.9 MB 5.3 MB/s eta 0:00:44
#      ------                                  43.4/272.9 MB 5.3 MB/s eta 0:00:44
#      ------                                  43.8/272.9 MB 5.4 MB/s eta 0:00:43
#      ------                                  44.1/272.9 MB 5.3 MB/s eta 0:00:43
#      ------                                  44.4/272.9 MB 5.3 MB/s eta 0:00:43
#      ------                                  44.7/272.9 MB 5.3 MB/s eta 0:00:44
#      ------                                  44.9/272.9 MB 5.3 MB/s eta 0:00:44
#      ------                                  45.2/272.9 MB 5.3 MB/s eta 0:00:44
#      ------                                  45.4/272.9 MB 5.4 MB/s eta 0:00:43
#      ------                                  45.7/272.9 MB 5.3 MB/s eta 0:00:44
#      ------                                  46.1/272.9 MB 5.4 MB/s eta 0:00:43
#      ------                                  46.3/272.9 MB 5.4 MB/s eta 0:00:42
#      ------                                  46.7/272.9 MB 5.5 MB/s eta 0:00:42
#      ------                                  46.9/272.9 MB 5.5 MB/s eta 0:00:42
#      ------                                  47.1/272.9 MB 5.5 MB/s eta 0:00:42
#      ------                                  47.4/272.9 MB 5.5 MB/s eta 0:00:41
#      ------                                  47.6/272.9 MB 5.5 MB/s eta 0:00:41
#      ------                                  47.9/272.9 MB 5.7 MB/s eta 0:00:40
#      ------                                  48.2/272.9 MB 5.7 MB/s eta 0:00:40
#      ------                                  48.4/272.9 MB 5.7 MB/s eta 0:00:40
#      ------                                  48.6/272.9 MB 5.7 MB/s eta 0:00:40
#      ------                                  48.8/272.9 MB 5.6 MB/s eta 0:00:40
#      -------                                 49.1/272.9 MB 5.5 MB/s eta 0:00:41
#      -------                                 49.4/272.9 MB 5.6 MB/s eta 0:00:40
#      -------                                 49.5/272.9 MB 5.6 MB/s eta 0:00:40
#      -------                                 49.7/272.9 MB 5.5 MB/s eta 0:00:41
#      -------                                 50.0/272.9 MB 5.6 MB/s eta 0:00:40
#      -------                                 50.2/272.9 MB 5.6 MB/s eta 0:00:40
#      -------                                 50.4/272.9 MB 5.6 MB/s eta 0:00:40
#      -------                                 50.6/272.9 MB 5.5 MB/s eta 0:00:41
#      -------                                 50.8/272.9 MB 5.5 MB/s eta 0:00:41
#      -------                                 51.0/272.9 MB 5.5 MB/s eta 0:00:40
#      -------                                 51.3/272.9 MB 5.5 MB/s eta 0:00:41
#      -------                                 51.5/272.9 MB 5.5 MB/s eta 0:00:41
#      -------                                 51.8/272.9 MB 5.5 MB/s eta 0:00:41
#      -------                                 52.0/272.9 MB 5.5 MB/s eta 0:00:41
#      -------                                 52.2/272.9 MB 5.4 MB/s eta 0:00:41
#      -------                                 52.3/272.9 MB 5.3 MB/s eta 0:00:42
#      -------                                 52.6/272.9 MB 5.3 MB/s eta 0:00:42
#      -------                                 52.8/272.9 MB 5.2 MB/s eta 0:00:43
#      -------                                 53.0/272.9 MB 5.3 MB/s eta 0:00:42
#      -------                                 53.3/272.9 MB 5.3 MB/s eta 0:00:42
#      -------                                 53.6/272.9 MB 5.2 MB/s eta 0:00:42
#      -------                                 53.7/272.9 MB 5.2 MB/s eta 0:00:43
#      -------                                 53.9/272.9 MB 5.2 MB/s eta 0:00:43
#      -------                                 54.1/272.9 MB 5.2 MB/s eta 0:00:43
#      -------                                 54.4/272.9 MB 5.2 MB/s eta 0:00:43
#      -------                                 54.7/272.9 MB 5.2 MB/s eta 0:00:43
#      -------                                 54.9/272.9 MB 5.2 MB/s eta 0:00:43
#      -------                                 55.2/272.9 MB 5.2 MB/s eta 0:00:43
#      -------                                 55.4/272.9 MB 5.1 MB/s eta 0:00:43
#      -------                                 55.7/272.9 MB 5.0 MB/s eta 0:00:44
#      --------                                56.1/272.9 MB 5.0 MB/s eta 0:00:44
#      --------                                56.3/272.9 MB 5.0 MB/s eta 0:00:44
#      --------                                56.5/272.9 MB 5.0 MB/s eta 0:00:44
#      --------                                56.7/272.9 MB 5.0 MB/s eta 0:00:44
#      --------                                56.9/272.9 MB 5.0 MB/s eta 0:00:44
# ...
#      -------------------------------------  215.0/219.4 kB 4.4 MB/s eta 0:00:01
#      -------------------------------------  215.0/219.4 kB 4.4 MB/s eta 0:00:01
#      -------------------------------------- 219.4/219.4 kB 1.1 MB/s eta 0:00:00
# Collecting PyWavelets>=1.1.1 (from scikit-image)
#   Downloading PyWavelets-1.4.1-cp311-cp311-win_amd64.whl (4.2 MB)
#                                               0.0/4.2 MB ? eta -:--:--
#      -                                        0.2/4.2 MB 3.1 MB/s eta 0:00:02
#      -----                                    0.5/4.2 MB 4.7 MB/s eta 0:00:01
#      -------                                  0.8/4.2 MB 5.1 MB/s eta 0:00:01
#      -----------                              1.2/4.2 MB 5.6 MB/s eta 0:00:01
#      -------------                            1.4/4.2 MB 5.7 MB/s eta 0:00:01
#      ----------------                         1.7/4.2 MB 5.6 MB/s eta 0:00:01
#      ------------------                       2.0/4.2 MB 5.7 MB/s eta 0:00:01
#      --------------------                     2.1/4.2 MB 5.5 MB/s eta 0:00:01
#      ----------------------                   2.3/4.2 MB 5.1 MB/s eta 0:00:01
#      ------------------------                 2.5/4.2 MB 5.0 MB/s eta 0:00:01
#      --------------------------               2.7/4.2 MB 4.9 MB/s eta 0:00:01
#      -----------------------------            3.1/4.2 MB 5.0 MB/s eta 0:00:01
#      --------------------------------         3.3/4.2 MB 5.0 MB/s eta 0:00:01
#      ----------------------------------       3.6/4.2 MB 5.0 MB/s eta 0:00:01
#      -----------------------------------      3.7/4.2 MB 4.9 MB/s eta 0:00:01
#      --------------------------------------   4.0/4.2 MB 4.8 MB/s eta 0:00:01
#      ---------------------------------------  4.2/4.2 MB 4.8 MB/s eta 0:00:01
#      ---------------------------------------  4.2/4.2 MB 4.8 MB/s eta 0:00:01
#      ---------------------------------------  4.2/4.2 MB 4.8 MB/s eta 0:00:01
#      ---------------------------------------  4.2/4.2 MB 4.8 MB/s eta 0:00:01
#      ---------------------------------------- 4.2/4.2 MB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=21 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-image) (23.1)
# Collecting lazy_loader>=0.2 (from scikit-image)
#   Downloading lazy_loader-0.2-py3-none-any.whl (8.6 kB)
# Installing collected packages: tifffile, PyWavelets, pillow, networkx, lazy_loader, imageio, scikit-image
# Successfully installed PyWavelets-1.4.1 imageio-2.31.1 lazy_loader-0.2 networkx-3.1 pillow-9.5.0 scikit-image-0.21.0 tifffile-2023.4.12
# Note: you may need to restart the kernel to use updated packages.
# Collecting matplotlib
#   Downloading matplotlib-3.7.1-cp311-cp311-win_amd64.whl (7.6 MB)
#                                               0.0/7.6 MB ? eta -:--:--
#                                               0.0/7.6 MB 1.4 MB/s eta 0:00:06
#                                               0.1/7.6 MB 787.7 kB/s eta 0:00:10
#                                               0.1/7.6 MB 737.3 kB/s eta 0:00:11
#                                               0.1/7.6 MB 774.0 kB/s eta 0:00:10
#                                               0.2/7.6 MB 798.5 kB/s eta 0:00:10
#      -                                        0.2/7.6 MB 801.7 kB/s eta 0:00:10
#      -                                        0.3/7.6 MB 827.5 kB/s eta 0:00:09
#      -                                        0.3/7.6 MB 819.2 kB/s eta 0:00:09
#      -                                        0.3/7.6 MB 840.2 kB/s eta 0:00:09
#      --                                       0.4/7.6 MB 782.8 kB/s eta 0:00:10
#      --                                       0.4/7.6 MB 815.2 kB/s eta 0:00:09
#      --                                       0.5/7.6 MB 850.4 kB/s eta 0:00:09
#      --                                       0.5/7.6 MB 852.0 kB/s eta 0:00:09
#      ---                                      0.6/7.6 MB 830.3 kB/s eta 0:00:09
#      ---                                      0.7/7.6 MB 878.9 kB/s eta 0:00:08
#      ---                                      0.7/7.6 MB 878.9 kB/s eta 0:00:08
#      ---                                      0.7/7.6 MB 878.1 kB/s eta 0:00:08
#      ----                                     0.8/7.6 MB 851.4 kB/s eta 0:00:09
#      ----                                     0.8/7.6 MB 885.2 kB/s eta 0:00:08
#      ----                                     0.9/7.6 MB 895.0 kB/s eta 0:00:08
#      ----                                     0.9/7.6 MB 890.0 kB/s eta 0:00:08
#      -----                                    1.0/7.6 MB 927.5 kB/s eta 0:00:08
#      -----                                    1.1/7.6 MB 925.2 kB/s eta 0:00:08
#      -----                                    1.1/7.6 MB 948.9 kB/s eta 0:00:07
#      ------                                   1.2/7.6 MB 958.5 kB/s eta 0:00:07
#      ------                                   1.3/7.6 MB 979.0 kB/s eta 0:00:07
#      ------                                   1.3/7.6 MB 983.6 kB/s eta 0:00:07
#      -------                                  1.4/7.6 MB 1.0 MB/s eta 0:00:07
#      --------                                 1.5/7.6 MB 1.0 MB/s eta 0:00:06
#      --------                                 1.6/7.6 MB 1.0 MB/s eta 0:00:06
#      --------                                 1.7/7.6 MB 1.1 MB/s eta 0:00:06
#      ---------                                1.7/7.6 MB 1.1 MB/s eta 0:00:06
#      ---------                                1.9/7.6 MB 1.1 MB/s eta 0:00:06
#      ----------                               1.9/7.6 MB 1.1 MB/s eta 0:00:06
#      ----------                               2.0/7.6 MB 1.1 MB/s eta 0:00:05
#      -----------                              2.1/7.6 MB 1.2 MB/s eta 0:00:05
#      -----------                              2.2/7.6 MB 1.2 MB/s eta 0:00:05
#      ------------                             2.3/7.6 MB 1.2 MB/s eta 0:00:05
#      ------------                             2.4/7.6 MB 1.2 MB/s eta 0:00:05
#      -------------                            2.5/7.6 MB 1.2 MB/s eta 0:00:05
#      --------------                           2.7/7.6 MB 1.3 MB/s eta 0:00:04
#      --------------                           2.7/7.6 MB 1.3 MB/s eta 0:00:04
#      ---------------                          2.9/7.6 MB 1.3 MB/s eta 0:00:04
#      ---------------                          3.0/7.6 MB 1.3 MB/s eta 0:00:04
#      ----------------                         3.1/7.6 MB 1.3 MB/s eta 0:00:04
#      ----------------                         3.2/7.6 MB 1.4 MB/s eta 0:00:04
#      -----------------                        3.4/7.6 MB 1.4 MB/s eta 0:00:04
#      ------------------                       3.5/7.6 MB 1.4 MB/s eta 0:00:03
#      -------------------                      3.7/7.6 MB 1.5 MB/s eta 0:00:03
#      --------------------                     3.9/7.6 MB 1.5 MB/s eta 0:00:03
#      --------------------                     4.0/7.6 MB 1.5 MB/s eta 0:00:03
#      ---------------------                    4.1/7.6 MB 1.5 MB/s eta 0:00:03
#      ----------------------                   4.2/7.6 MB 1.5 MB/s eta 0:00:03
#      ----------------------                   4.3/7.6 MB 1.5 MB/s eta 0:00:03
#      -----------------------                  4.5/7.6 MB 1.6 MB/s eta 0:00:02
#      ------------------------                 4.7/7.6 MB 1.6 MB/s eta 0:00:02
#      ------------------------                 4.7/7.6 MB 1.6 MB/s eta 0:00:02
#      -------------------------                4.9/7.6 MB 1.6 MB/s eta 0:00:02
#      --------------------------               5.0/7.6 MB 1.6 MB/s eta 0:00:02
#      ---------------------------              5.2/7.6 MB 1.7 MB/s eta 0:00:02
#      ---------------------------              5.3/7.6 MB 1.7 MB/s eta 0:00:02
#      ---------------------------              5.3/7.6 MB 1.7 MB/s eta 0:00:02
#      ----------------------------             5.4/7.6 MB 1.7 MB/s eta 0:00:02
#      -----------------------------            5.6/7.6 MB 1.7 MB/s eta 0:00:02
#      -----------------------------            5.6/7.6 MB 1.7 MB/s eta 0:00:02
#      ------------------------------           5.8/7.6 MB 1.7 MB/s eta 0:00:02
#      -------------------------------          6.0/7.6 MB 1.7 MB/s eta 0:00:01
#      --------------------------------         6.2/7.6 MB 1.8 MB/s eta 0:00:01
#      ---------------------------------        6.4/7.6 MB 1.8 MB/s eta 0:00:01
#      ----------------------------------       6.6/7.6 MB 1.8 MB/s eta 0:00:01
#      -----------------------------------      6.8/7.6 MB 1.9 MB/s eta 0:00:01
#      ------------------------------------     7.0/7.6 MB 1.9 MB/s eta 0:00:01
#      -------------------------------------    7.2/7.6 MB 1.9 MB/s eta 0:00:01
#      --------------------------------------   7.4/7.6 MB 1.9 MB/s eta 0:00:01
#      ---------------------------------------  7.6/7.6 MB 2.0 MB/s eta 0:00:01
#      ---------------------------------------  7.6/7.6 MB 2.0 MB/s eta 0:00:01
#      ---------------------------------------  7.6/7.6 MB 2.0 MB/s eta 0:00:01
#      ---------------------------------------  7.6/7.6 MB 2.0 MB/s eta 0:00:01
#      ---------------------------------------  7.6/7.6 MB 2.0 MB/s eta 0:00:01
#      ---------------------------------------  7.6/7.6 MB 2.0 MB/s eta 0:00:01
#      ---------------------------------------  7.6/7.6 MB 2.0 MB/s eta 0:00:01
#      ---------------------------------------  7.6/7.6 MB 2.0 MB/s eta 0:00:01
#      ---------------------------------------  7.6/7.6 MB 2.0 MB/s eta 0:00:01
#      ---------------------------------------- 7.6/7.6 MB 1.8 MB/s eta 0:00:00
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.1.0-cp311-cp311-win_amd64.whl (470 kB)
#                                               0.0/470.9 kB ? eta -:--:--
#      --------------------                   256.0/470.9 kB 7.9 MB/s eta 0:00:01
#      -------------------------------------  460.8/470.9 kB 4.8 MB/s eta 0:00:01
#      -------------------------------------  460.8/470.9 kB 4.8 MB/s eta 0:00:01
#      -------------------------------------  460.8/470.9 kB 4.8 MB/s eta 0:00:01
#      -------------------------------------  460.8/470.9 kB 4.8 MB/s eta 0:00:01
#      -------------------------------------  460.8/470.9 kB 4.8 MB/s eta 0:00:01
#      -------------------------------------- 470.9/470.9 kB 1.3 MB/s eta 0:00:00
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.40.0-cp311-cp311-win_amd64.whl (1.9 MB)
#                                               0.0/1.9 MB ? eta -:--:--
#      ----                                     0.2/1.9 MB 5.8 MB/s eta 0:00:01
#      --------                                 0.4/1.9 MB 5.1 MB/s eta 0:00:01
#      -----------                              0.5/1.9 MB 4.3 MB/s eta 0:00:01
#      ---------------                          0.8/1.9 MB 4.0 MB/s eta 0:00:01
#      -------------------                      1.0/1.9 MB 3.8 MB/s eta 0:00:01
#      -----------------------                  1.2/1.9 MB 3.9 MB/s eta 0:00:01
#      ---------------------------              1.3/1.9 MB 3.8 MB/s eta 0:00:01
#      -----------------------------            1.4/1.9 MB 3.7 MB/s eta 0:00:01
#      ----------------------------------       1.7/1.9 MB 3.9 MB/s eta 0:00:01
#      ---------------------------------------  1.9/1.9 MB 4.0 MB/s eta 0:00:01
#      ---------------------------------------  1.9/1.9 MB 4.0 MB/s eta 0:00:01
#      ---------------------------------------  1.9/1.9 MB 4.0 MB/s eta 0:00:01
#      ---------------------------------------  1.9/1.9 MB 4.0 MB/s eta 0:00:01
#      ---------------------------------------  1.9/1.9 MB 4.0 MB/s eta 0:00:01
#      ---------------------------------------  1.9/1.9 MB 4.0 MB/s eta 0:00:01
#      ---------------------------------------  1.9/1.9 MB 4.0 MB/s eta 0:00:01
#      ---------------------------------------  1.9/1.9 MB 4.0 MB/s eta 0:00:01
#      ---------------------------------------  1.9/1.9 MB 4.0 MB/s eta 0:00:01
#      ---------------------------------------  1.9/1.9 MB 4.0 MB/s eta 0:00:01
#      ---------------------------------------  1.9/1.9 MB 4.0 MB/s eta 0:00:01
#      ---------------------------------------  1.9/1.9 MB 4.0 MB/s eta 0:00:01
#      ---------------------------------------  1.9/1.9 MB 4.0 MB/s eta 0:00:01
#      ---------------------------------------  1.9/1.9 MB 4.0 MB/s eta 0:00:01
#      ---------------------------------------  1.9/1.9 MB 4.0 MB/s eta 0:00:01
#      ---------------------------------------  1.9/1.9 MB 4.0 MB/s eta 0:00:01
#      ---------------------------------------  1.9/1.9 MB 4.0 MB/s eta 0:00:01
#      ---------------------------------------  1.9/1.9 MB 4.0 MB/s eta 0:00:01
#      ---------------------------------------  1.9/1.9 MB 4.0 MB/s eta 0:00:01
#      ---------------------------------------- 1.9/1.9 MB 1.4 MB/s eta 0:00:00
# Collecting kiwisolver>=1.0.1 (from matplotlib)
#   Downloading kiwisolver-1.4.4-cp311-cp311-win_amd64.whl (55 kB)
#                                               0.0/55.4 kB ? eta -:--:--
#      ------------------------------------     51.2/55.4 kB 2.6 MB/s eta 0:00:01
#      ------------------------------------     51.2/55.4 kB 2.6 MB/s eta 0:00:01
#      ------------------------------------     51.2/55.4 kB 2.6 MB/s eta 0:00:01
#      ------------------------------------     51.2/55.4 kB 2.6 MB/s eta 0:00:01
#      ------------------------------------     51.2/55.4 kB 2.6 MB/s eta 0:00:01
#      ------------------------------------     51.2/55.4 kB 2.6 MB/s eta 0:00:01
#      ------------------------------------     51.2/55.4 kB 2.6 MB/s eta 0:00:01
#      ------------------------------------     51.2/55.4 kB 2.6 MB/s eta 0:00:01
#      ------------------------------------     51.2/55.4 kB 2.6 MB/s eta 0:00:01
#      ------------------------------------     51.2/55.4 kB 2.6 MB/s eta 0:00:01
#      ------------------------------------     51.2/55.4 kB 2.6 MB/s eta 0:00:01
#      --------------------------------------- 55.4/55.4 kB 80.2 kB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (9.5.0)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.1.0-py3-none-any.whl (102 kB)
#                                               0.0/102.6 kB ? eta -:--:--
#      ---------------------------------------  102.4/102.6 kB ? eta -:--:--
#      ---------------------------------------  102.4/102.6 kB ? eta -:--:--
#      ---------------------------------------  102.4/102.6 kB ? eta -:--:--
#      ---------------------------------------  102.4/102.6 kB ? eta -:--:--
#      ---------------------------------------  102.4/102.6 kB ? eta -:--:--
#      ---------------------------------------  102.4/102.6 kB ? eta -:--:--
#      ------------------------------------ 102.6/102.6 kB 295.2 kB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.1.0 cycler-0.11.0 fonttools-4.40.0 kiwisolver-1.4.4 matplotlib-3.7.1 pyparsing-3.1.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Step 1: Import the libraries 📚

# %%
import tensorflow as tf      # Deep Learning library
import numpy as np           # Handle matrices
from vizdoom import *        # Doom Environment

import random                # Handling random number generation
import time                  # Handling time calculation
from skimage import transform# Help us to preprocess the frames

from collections import deque# Ordered collection with ends
import matplotlib.pyplot as plt # Display graphs

import warnings # This ignore all the warning messages that are normally printed during the training because of skiimage
warnings.filterwarnings('ignore')
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# ## Step 2: Create our environment 🎮
# - Now that we imported the libraries/dependencies, we will create our environment.
# - Doom environment takes:
#     - A `configuration file` that **handle all the options** (size of the frame, possible actions...)
#     - A `scenario file`: that **generates the correct scenario** (in our case basic **but you're invited to try other scenarios**).
# - Note: We have 3 possible actions `[[0,0,1], [1,0,0], [0,1,0]]` so we don't need to do one hot encoding (thanks to < a href="https://stackoverflow.com/users/2237916/silgon">silgon</a> for figuring out.
#
# ### Our environment
# <img src="assets/doom.png" style="max-width:500px;" alt="Doom"/>
#
# - A monster is spawned **randomly somewhere along the opposite wall**.
# - Player can only go **left/right and shoot**.
# - 1 hit is enough **to kill the monster**.
# - Episode finishes when **monster is killed or on timeout (300)**.
# <br><br>
# REWARDS:
#
# - +101 for killing the monster
# - -5 for missing
# - Episode ends after killing the monster or on timeout.
# - living reward = -1

# %%
"""
Here we create our environment
"""
def create_environment():
    game = DoomGame()

    # Load the correct configuration
    game.load_config("basic.cfg")

    # Load the correct scenario (in our case basic scenario)
    game.set_doom_scenario_path("basic.wad")

    # For Google Collab
    game.set_window_visible(False)

    game.init()

    # Here our possible actions
    left = [1, 0, 0]
    right = [0, 1, 0]
    shoot = [0, 0, 1]
    possible_actions = [left, right, shoot]

    return game, possible_actions

"""
Here we performing random action to test the environment
"""
def test_environment():
    game = DoomGame()
    game.load_config("basic.cfg")
    game.set_doom_scenario_path("basic.wad")
    game.init()
    shoot = [0, 0, 1]
    left = [1, 0, 0]
    right = [0, 1, 0]
    actions = [shoot, left, right]

    episodes = 10
    for i in range(episodes):
        game.new_episode()
        while not game.is_episode_finished():
            state = game.get_state()
            img = state.screen_buffer
            misc = state.game_variables
            action = random.choice(actions)
            print(action)
            reward = game.make_action(action)
            print ("\treward:", reward)
            time.sleep(0.02)
        print ("Result:", game.get_total_reward())
        time.sleep(2)
    game.close()

# %%
game, possible_actions = create_environment()

# %% [markdown]
# ## Step 3: Define the preprocessing functions ⚙️
# ### preprocess_frame
# Preprocessing is an important step, <b>because we want to reduce the complexity of our states to reduce the computation time needed for training.</b>
# <br><br>
# Our steps:
# - Grayscale each of our frames (because <b> color does not add important information </b>). But this is already done by the config file.
# - Crop the screen (in our case we remove the roof because it contains no information)
# - We normalize pixel values
# - Finally we resize the preprocessed frame

# %%
"""
    preprocess_frame:
    Take a frame.
    Resize it.
        __________________
        |                 |
        |                 |
        |                 |
        |                 |
        |_________________|

        to
        _____________
        |            |
        |            |
        |            |
        |____________|
    Normalize it.

    return preprocessed_frame

    """
def preprocess_frame(frame):
    # Greyscale frame already done in our vizdoom config
    # x = np.mean(frame,-1)

    # Crop the screen (remove the roof because it contains no information)
    cropped_frame = frame[30:-10,30:-30]

    # Normalize Pixel Values
    normalized_frame = cropped_frame/255.0

    # Resize
    preprocessed_frame = transform.resize(normalized_frame, [60,60])

    return preprocessed_frame

# %% [markdown]
# ### stack_frames
# 👏 This part was made possible thanks to help of <a href="https://github.com/Miffyli">Anssi</a><br>
#
# As explained in this really <a href="https://danieltakeshi.github.io/2016/11/25/frame-skipping-and-preprocessing-for-deep-q-networks-on-atari-2600-games/">  good article </a> we stack frames.
#
# Stacking frames is really important because it helps us to **give have a sense of motion to our Neural Network.**
#
# - First we preprocess frame
# - Then we append the frame to the deque that automatically **removes the oldest frame**
# - Finally we **build the stacked state**
#
# This is how work stack:
# - For the first frame, we feed 4 frames
# - At each timestep, **we add the new frame to deque and then we stack them to form a new stacked frame**
# - And so on
# <img src="https://raw.githubusercontent.com/simoninithomas/Deep_reinforcement_learning_Course/master/DQN/Space%20Invaders/assets/stack_frames.png" alt="stack">
# - If we're done, **we create a new stack with 4 new frames (because we are in a new episode)**.

# %%
stack_size = 2 # We stack 4 frames

# Initialize deque with zero-images one array for each image
stacked_frames  =  deque([np.zeros((60,60), dtype=np.int) for i in range(stack_size)], maxlen=2)

def stack_frames(stacked_frames, state, is_new_episode):
    # Preprocess frame
    frame = preprocess_frame(state)

    if is_new_episode:
        # Clear our stacked_frames
        stacked_frames = deque([np.zeros((60,60), dtype=np.int) for i in range(stack_size)], maxlen=2)

        # Because we're in a new episode, copy the same frame 4x
        stacked_frames.append(frame)
        stacked_frames.append(frame)
        stacked_frames.append(frame)

        # Stack the frames
        stacked_state = np.stack(stacked_frames, axis=2)

    else:
        # Append frame to deque, automatically removes the oldest frame
        stacked_frames.append(frame)

        # Build the stacked state (first dimension specifies different frames)
        stacked_state = np.stack(stacked_frames, axis=2)

    return stacked_state, stacked_frames

# %% [markdown]
# ## Step 4: Set up our hyperparameters ⚗️
# In this part we'll set up our different hyperparameters. But when you implement a Neural Network by yourself you will **not implement hyperparamaters at once but progressively**.
#
# - First, you begin by defining the neural networks hyperparameters when you implement the model.
# - Then, you'll add the training hyperparameters when you implement the training algorithm.

# %%
### MODEL HYPERPARAMETERS
state_size = [60,60,2]      # Our input is a stack of 4 frames hence 84x84x4 (Width, height, channels)
action_size = game.get_available_buttons_size()              # 3 possible actions: left, right, shoot
learning_rate =  0.0004      # Alpha (aka learning rate)

### TRAINING HYPERPARAMETERS
total_episodes = 300        # Total episodes for training
max_steps = 100              # Max possible steps in an episode
batch_size = 64

# Exploration parameters for epsilon greedy strategy
explore_start = 1.0            # exploration probability at start
explore_stop = 0.01            # minimum exploration probability
decay_rate = 0.0001            # exponential decay rate for exploration prob

# Q learning hyperparameters
gamma = 0.95               # Discounting rate

### MEMORY HYPERPARAMETERS
pretrain_length = batch_size   # Number of experiences stored in the Memory when initialized for the first time
memory_size = 1000000          # Number of experiences the Memory can keep

### MODIFY THIS TO FALSE IF YOU JUST WANT TO SEE THE TRAINED AGENT
training = True

## TURN THIS TO TRUE IF YOU WANT TO RENDER THE ENVIRONMENT
episode_render = True

# %% [markdown]
# ## Step 5: Create our Deep Q-learning Neural Network model 🧠
# <img src="assets/model.png" alt="Model" />
# This is our Deep Q-learning model:
# - We take a stack of 4 frames as input
# - It passes through 3 convnets
# - Then it is flatened
# - Finally it passes through 2 FC layers
# - It outputs a Q value for each actions

# %%
class DQNetwork:
    def __init__(self, state_size, action_size, learning_rate, name='DQNetwork'):
        self.state_size = state_size
        self.action_size = action_size
        self.learning_rate = learning_rate

        with tf.compat.v1.variable_scope(name):
            # We create the placeholders
            # *state_size means that we take each elements of state_size in tuple hence is like if we wrote
            # [None, 84, 84, 4]
            self.inputs_ = tf.compat.v1.placeholder(tf.float32, [None, *state_size], name="inputs")
            self.actions_ = tf.compat.v1.placeholder(tf.float32, [None, 3], name="actions_")

            # Remember that target_Q is the R(s,a) + ymax Qhat(s', a')
            self.target_Q = tf.compat.v1.placeholder(tf.float32, [None], name="target")

            """
            First convnet:
            CNN
            BatchNormalization
            ELU
            """
            # Input is 84x84x4
            self.conv1 = tf.compat.v1.layers.conv2d(inputs = self.inputs_,
                                         filters = 32,
                                         kernel_size = [8,8],
                                         strides = [4,4],
                                         padding = "VALID",
                                          kernel_initializer=tf.compat.v1.keras.initializers.VarianceScaling(scale=1.0, mode="fan_avg", distribution="uniform"),
                                         name = "conv1")

            self.conv1_batchnorm = tf.compat.v1.layers.batch_normalization(self.conv1,
                                                   training = True,
                                                   epsilon = 1e-5,
                                                     name = 'batch_norm1')

            self.conv1_out = tf.nn.elu(self.conv1_batchnorm, name="conv1_out")
            ## --> [20, 20, 32]


            """
            Second convnet:
            CNN
            BatchNormalization
            ELU
            """
            self.conv2 = tf.compat.v1.layers.conv2d(inputs = self.conv1_out,
                                 filters = 64,
                                 kernel_size = [4,4],
                                 strides = [2,2],
                                 padding = "VALID",
                                kernel_initializer=tf.compat.v1.keras.initializers.VarianceScaling(scale=1.0, mode="fan_avg", distribution="uniform"),
                                 name = "conv2")

            self.conv2_batchnorm = tf.compat.v1.layers.batch_normalization(self.conv2,
                                                   training = True,
                                                   epsilon = 1e-5,
                                                     name = 'batch_norm2')

            self.conv2_out = tf.nn.elu(self.conv2_batchnorm, name="conv2_out")
            ## --> [9, 9, 64]


            """
            Third convnet:
            CNN
            BatchNormalization
            ELU
            """
            self.conv3 = tf.compat.v1.layers.conv2d(inputs = self.conv2_out,
                                 filters = 128,
                                 kernel_size = [4,4],
                                 strides = [2,2],
                                 padding = "VALID",
                                kernel_initializer=tf.compat.v1.keras.initializers.VarianceScaling(scale=1.0, mode="fan_avg", distribution="uniform"),
                                 name = "conv3")

            self.conv3_batchnorm = tf.compat.v1.layers.batch_normalization(self.conv3,
                                                   training = True,
                                                   epsilon = 1e-5,
                                                     name = 'batch_norm3')

            self.conv3_out = tf.nn.elu(self.conv3_batchnorm, name="conv3_out")
            ## --> [3, 3, 128]


            self.flatten = tf.compat.v1.layers.flatten(self.conv3_out)
            ## --> [1152]


            self.fc = tf.compat.v1.layers.dense(inputs = self.flatten,
                                  units = 512,
                                  activation = tf.nn.elu,
                                       kernel_initializer=tf.compat.v1.keras.initializers.VarianceScaling(scale=1.0, mode="fan_avg", distribution="uniform"),
                                name="fc1")


            self.output = tf.compat.v1.layers.dense(inputs = self.fc,
                                           kernel_initializer=tf.compat.v1.keras.initializers.VarianceScaling(scale=1.0, mode="fan_avg", distribution="uniform"),
                                          units = 3,
                                        activation=None)


            # Q is our predicted Q value.
            self.Q = tf.reduce_sum(tf.multiply(self.output, self.actions_), axis=1)


            # The loss is the difference between our predicted Q_values and the Q_target
            # Sum(Qtarget - Q)^2
            self.loss = tf.reduce_mean(tf.square(self.target_Q - self.Q))

            self.optimizer = tf.compat.v1.train.RMSPropOptimizer(self.learning_rate).minimize(self.loss)

# %%
tf.compat.v1.disable_eager_execution()

# %%
# Reset the graph
tf.compat.v1.reset_default_graph()

# Instantiate the DQNetwork
DQNetwork = DQNetwork(state_size, action_size, learning_rate)

# %% [markdown]
# ## Step 6: Experience Replay 🔁
# Now that we create our Neural Network, **we need to implement the Experience Replay method.** <br><br>
# Here we'll create the Memory object that creates a deque.A deque (double ended queue) is a data type that **removes the oldest element each time that you add a new element.**
#
# This part was taken from Udacity : <a href="https://github.com/udacity/deep-learning/blob/master/reinforcement/Q-learning-cart.ipynb" Cartpole DQN</a>

# %%
class Memory():
    def __init__(self, max_size):
        self.buffer = deque(maxlen = max_size)

    def add(self, experience):
        self.buffer.append(experience)

    def sample(self, batch_size):
        buffer_size = len(self.buffer)
        index = np.random.choice(np.arange(buffer_size),
                                size = batch_size,
                                replace = False)

        return [self.buffer[i] for i in index]

# %% [markdown]
# Here we'll **deal with the empty memory problem**: we pre-populate our memory by taking random actions and storing the experience (state, action, reward, new_state).

# %%
# Instantiate memory
memory = Memory(max_size = memory_size)

# Render the environment
game.new_episode()

for i in range(pretrain_length):
    # If it's the first step
    if i == 0:
        # First we need a state
        state = game.get_state().screen_buffer
        state, stacked_frames = stack_frames(stacked_frames, state, True)

    # Random action
    action = random.choice(possible_actions)

    # Get the rewards
    reward = game.make_action(action)

    # Look if the episode is finished
    done = game.is_episode_finished()

    # If we're dead
    if done:
        # We finished the episode
        next_state = np.zeros(state.shape)

        # Add experience to memory
        memory.add((state, action, reward, next_state, done))

        # Start a new episode
        game.new_episode()

        # First we need a state
        state = game.get_state().screen_buffer

        # Stack the frames
        state, stacked_frames = stack_frames(stacked_frames, state, True)

    else:
        # Get the next state
        next_state = game.get_state().screen_buffer
        next_state, stacked_frames = stack_frames(stacked_frames, next_state, False)

        # Add experience to memory
        memory.add((state, action, reward, next_state, done))

        # Our state is now the next_state
        state = next_state

# %% [markdown]
# ## Step 7: Set up Tensorboard 📊
# For more information about tensorboard, please watch this <a href="https://www.youtube.com/embed/eBbEDRsCmv4">excellent 30min tutorial</a> <br><br>
# To launch tensorboard : `tensorboard --logdir=/tensorboard/dqn/1`

# %%
# Setup TensorBoard Writer
writer = tf.compat.v1.summary.FileWriter("/tensorboard/dqn/1")

## Losses
tf.compat.v1.summary.scalar("Loss", DQNetwork.loss)

write_op = tf.compat.v1.summary.merge_all()

# %% [markdown]
# ## Step 8: Train our Agent 🏃‍♂️
#
# Our algorithm:
# <br>
# * Initialize the weights
# * Init the environment
# * Initialize the decay rate (that will use to reduce epsilon)
# <br><br>
# * **For** episode to max_episode **do**
#     * Make new episode
#     * Set step to 0
#     * Observe the first state $s_0$
#     <br><br>
#     * **While** step < max_steps **do**:
#         * Increase decay_rate
#         * With $\epsilon$ select a random action $a_t$, otherwise select $a_t = \mathrm{argmax}_a Q(s_t,a)$
#         * Execute action $a_t$ in simulator and observe reward $r_{t+1}$ and new state $s_{t+1}$
#         * Store transition $<s_t, a_t, r_{t+1}, s_{t+1}>$ in memory $D$
#         * Sample random mini-batch from $D$: $<s, a, r, s'>$
#         * Set $\hat{Q} = r$ if the episode ends at $+1$, otherwise set $\hat{Q} = r + \gamma \max_{a'}{Q(s', a')}$
#         * Make a gradient descent step with loss $(\hat{Q} - Q(s, a))^2$
#     * **endfor**
#     <br><br>
# * **endfor**

# %%
"""
This function will do the part
With Ïµ select a random action atat, otherwise select at=argmaxaQ(st,a)
"""
def predict_action(explore_start, explore_stop, decay_rate, decay_step, state, actions):
    ## EPSILON GREEDY STRATEGY
    # Choose action a from state s using epsilon greedy.
    ## First we randomize a number
    exp_exp_tradeoff = np.random.rand()

    # Here we'll use an improved version of our epsilon greedy strategy used in Q-learning notebook
    explore_probability = explore_stop + (explore_start - explore_stop) * np.exp(-decay_rate * decay_step)

    if (explore_probability > exp_exp_tradeoff):
        # Make a random action (exploration)
        action = random.choice(possible_actions)

    else:
        # Get action from Q-network (exploitation)
        # Estimate the Qs values state
        Qs = sess.run(DQNetwork.output, feed_dict = {DQNetwork.inputs_: state.reshape((1, *state.shape))})

        # Take the biggest Q value (= the best action)
        choice = np.argmax(Qs)
        action = possible_actions[int(choice)]

    return action, explore_probability

# %%
# Saver will help us to save our model
saver = tf.compat.v1.train.Saver()

if training == True:
    with tf.compat.v1.Session() as sess:
        # Initialize the variables
        sess.run(tf.compat.v1.global_variables_initializer())

        # Initialize the decay rate (that will use to reduce epsilon)
        decay_step = 0

        # Init the game
        game.init()

        for episode in range(total_episodes):
            # Set step to 0
            step = 0

            # Initialize the rewards of the episode
            episode_rewards = []

            # Make a new episode and observe the first state
            game.new_episode()
            state = game.get_state().screen_buffer

            # Remember that stack frame function also call our preprocess function.
            state, stacked_frames = stack_frames(stacked_frames, state, True)

            while step < max_steps:
                step += 1

                # Increase decay_step
                decay_step +=1

                # Predict the action to take and take it
                action, explore_probability = predict_action(explore_start, explore_stop, decay_rate, decay_step, state, possible_actions)

                # Do the action
                reward = game.make_action(action)

                # Look if the episode is finished
                done = game.is_episode_finished()

                # Add the reward to total reward
                episode_rewards.append(reward)

                # If the game is finished
                if done:
                    # the episode ends so no next state
                    next_state = np.zeros((84,84), dtype=np.int)
                    next_state, stacked_frames = stack_frames(stacked_frames, next_state, False)

                    # Set step = max_steps to end the episode
                    step = max_steps

                    # Get the total reward of the episode
                    total_reward = np.sum(episode_rewards)

                    print('Episode: {}'.format(episode),
                              'Total reward: {}'.format(total_reward),
                              'Training loss: {:.4f}'.format(loss),
                              'Explore P: {:.4f}'.format(explore_probability))

                    memory.add((state, action, reward, next_state, done))

                else:
                    # Get the next state
                    next_state = game.get_state().screen_buffer

                    # Stack the frame of the next_state
                    next_state, stacked_frames = stack_frames(stacked_frames, next_state, False)


                    # Add experience to memory
                    memory.add((state, action, reward, next_state, done))

                    # st+1 is now our current state
                    state = next_state


                ### LEARNING PART
                # Obtain random mini-batch from memory
                batch = memory.sample(batch_size)
                states_mb = np.array([each[0] for each in batch], ndmin=3)
                actions_mb = np.array([each[1] for each in batch])
                rewards_mb = np.array([each[2] for each in batch])
                next_states_mb = np.array([each[3] for each in batch], ndmin=3)
                dones_mb = np.array([each[4] for each in batch])

                target_Qs_batch = []

                 # Get Q values for next_state
                Qs_next_state = sess.run(DQNetwork.output, feed_dict = {DQNetwork.inputs_: next_states_mb})

                # Set Q_target = r if the episode ends at s+1, otherwise set Q_target = r + gamma*maxQ(s', a')
                for i in range(0, len(batch)):
                    terminal = dones_mb[i]

                    # If we are in a terminal state, only equals reward
                    if terminal:
                        target_Qs_batch.append(rewards_mb[i])

                    else:
                        target = rewards_mb[i] + gamma * np.max(Qs_next_state[i])
                        target_Qs_batch.append(target)


                targets_mb = np.array([each for each in target_Qs_batch])

                loss, _ = sess.run([DQNetwork.loss, DQNetwork.optimizer],
                                    feed_dict={DQNetwork.inputs_: states_mb,
                                               DQNetwork.target_Q: targets_mb,
                                               DQNetwork.actions_: actions_mb})

                # Write TF Summaries
                summary = sess.run(write_op, feed_dict={DQNetwork.inputs_: states_mb,
                                                   DQNetwork.target_Q: targets_mb,
                                                   DQNetwork.actions_: actions_mb})
                writer.add_summary(summary, episode)
                writer.flush()

            # Save model every 5 episodes
            if episode % 5 == 0:
                save_path = saver.save(sess, "./models/model.ckpt")
                print("Model Saved")
# Out:
# Episode: 0 Total reward: 94.0 Training loss: 404.8019 Explore P: 0.9993
# Model Saved
# Episode: 1 Total reward: 95.0 Training loss: 430.8832 Explore P: 0.9987
# Episode: 2 Total reward: 43.0 Training loss: 20.0658 Explore P: 0.9940
# Episode: 3 Total reward: 26.0 Training loss: 36.5802 Explore P: 0.9881
# Episode: 4 Total reward: 92.0 Training loss: 24.3061 Explore P: 0.9872
# Episode: 5 Total reward: 90.0 Training loss: 109.7634 Explore P: 0.9861
# Model Saved
# Episode: 8 Total reward: 70.0 Training loss: 11.5784 Explore P: 0.9643
# Episode: 10 Total reward: 93.0 Training loss: 12.7629 Explore P: 0.9541
# Model Saved
# Episode: 14 Total reward: 66.0 Training loss: 21.9104 Explore P: 0.9234
# Model Saved
# Episode: 16 Total reward: 94.0 Training loss: 20.0092 Explore P: 0.9137
# Episode: 17 Total reward: 95.0 Training loss: 23.8924 Explore P: 0.9132
# Episode: 19 Total reward: 94.0 Training loss: 5.6686 Explore P: 0.9036
# Model Saved
# Episode: 21 Total reward: 94.0 Training loss: 3.8221 Explore P: 0.8940
# Episode: 23 Total reward: 95.0 Training loss: 4.2872 Explore P: 0.8847
# Model Saved
# Episode: 26 Total reward: 69.0 Training loss: 65.4682 Explore P: 0.8651
# Episode: 27 Total reward: 89.0 Training loss: 9.6150 Explore P: 0.8641
# Episode: 28 Total reward: 94.0 Training loss: 8.2240 Explore P: 0.8635
# Episode: 29 Total reward: 87.0 Training loss: 6.7024 Explore P: 0.8623
# Episode: 30 Total reward: 95.0 Training loss: 10.9475 Explore P: 0.8618
# Model Saved
# Episode: 33 Total reward: 94.0 Training loss: 3.0636 Explore P: 0.8443
# Episode: 34 Total reward: -23.0 Training loss: 6.2159 Explore P: 0.8361
# Episode: 35 Total reward: 74.0 Training loss: 6.0901 Explore P: 0.8343
# Model Saved
# Episode: 37 Total reward: 95.0 Training loss: 6.1336 Explore P: 0.8256
# Episode: 38 Total reward: 52.0 Training loss: 13.2178 Explore P: 0.8224
# Episode: 40 Total reward: 93.0 Training loss: 5.9167 Explore P: 0.8137
# Model Saved
# Episode: 41 Total reward: 95.0 Training loss: 7.0828 Explore P: 0.8132
# Episode: 42 Total reward: 95.0 Training loss: 2.6814 Explore P: 0.8127
# Episode: 43 Total reward: 93.0 Training loss: 8.3682 Explore P: 0.8121
# Episode: 44 Total reward: 94.0 Training loss: 5.2770 Explore P: 0.8115
# Episode: 45 Total reward: 41.0 Training loss: 14.6954 Explore P: 0.8075
# Model Saved
# Episode: 46 Total reward: 95.0 Training loss: 5.3924 Explore P: 0.8070
# Episode: 49 Total reward: 93.0 Training loss: 6.4956 Explore P: 0.7906
# Episode: 50 Total reward: 94.0 Training loss: 11.1483 Explore P: 0.7901
# Model Saved
# Episode: 51 Total reward: 95.0 Training loss: 10.7606 Explore P: 0.7896
# Episode: 52 Total reward: 25.0 Training loss: 18.7841 Explore P: 0.7849
# Episode: 53 Total reward: 91.0 Training loss: 8.2624 Explore P: 0.7841
# Episode: 54 Total reward: 36.0 Training loss: 11.9313 Explore P: 0.7799
# Model Saved
# Episode: 56 Total reward: 95.0 Training loss: 23.2107 Explore P: 0.7717
# Episode: 59 Total reward: 68.0 Training loss: 8.0984 Explore P: 0.7546
# Episode: 60 Total reward: 95.0 Training loss: 11.4803 Explore P: 0.7541
# Model Saved
# Episode: 61 Total reward: 95.0 Training loss: 18.4158 Explore P: 0.7537
# Episode: 62 Total reward: 20.0 Training loss: 13.8690 Explore P: 0.7488
# Episode: 64 Total reward: 95.0 Training loss: 7.7727 Explore P: 0.7410
# Episode: 65 Total reward: 95.0 Training loss: 13.1826 Explore P: 0.7406
# Model Saved
# Episode: 66 Total reward: 93.0 Training loss: 6.4334 Explore P: 0.7400
# Episode: 67 Total reward: 93.0 Training loss: 6.6497 Explore P: 0.7394
# Episode: 69 Total reward: 95.0 Training loss: 8.4100 Explore P: 0.7317
# Model Saved
# Episode: 71 Total reward: 94.0 Training loss: 7.6887 Explore P: 0.7240
# Episode: 72 Total reward: 50.0 Training loss: 13.4864 Explore P: 0.7211
# Episode: 74 Total reward: 42.0 Training loss: 8.2831 Explore P: 0.7106
# Episode: 75 Total reward: 66.0 Training loss: 16.0871 Explore P: 0.7085
# Model Saved
# Episode: 76 Total reward: 95.0 Training loss: 12.4626 Explore P: 0.7081
# Episode: 77 Total reward: 74.0 Training loss: 15.3452 Explore P: 0.7065
# Episode: 78 Total reward: 14.0 Training loss: 11.8052 Explore P: 0.7019
# Episode: 80 Total reward: 94.0 Training loss: 11.7903 Explore P: 0.6945
# Model Saved
# Episode: 81 Total reward: 0.0 Training loss: 7.0295 Explore P: 0.6890
# Episode: 82 Total reward: 92.0 Training loss: 9.3289 Explore P: 0.6884
# Episode: 83 Total reward: 95.0 Training loss: 14.8553 Explore P: 0.6880
# Episode: 84 Total reward: 95.0 Training loss: 11.7968 Explore P: 0.6876
# Episode: 85 Total reward: 92.0 Training loss: 8.0713 Explore P: 0.6870
# Model Saved
# Episode: 86 Total reward: 24.0 Training loss: 8.6074 Explore P: 0.6824
# Episode: 87 Total reward: 94.0 Training loss: 8.3867 Explore P: 0.6820
# Episode: 89 Total reward: 91.0 Training loss: 11.2372 Explore P: 0.6746
# Model Saved
# Episode: 91 Total reward: 94.0 Training loss: 9.9810 Explore P: 0.6675
# Episode: 93 Total reward: 95.0 Training loss: 13.1837 Explore P: 0.6606
# Episode: 94 Total reward: 57.0 Training loss: 8.2383 Explore P: 0.6584
# Episode: 95 Total reward: 91.0 Training loss: 6.8179 Explore P: 0.6578
# Model Saved
# Episode: 96 Total reward: -7.0 Training loss: 4.4431 Explore P: 0.6521
# Episode: 97 Total reward: 23.0 Training loss: 9.5653 Explore P: 0.6480
# Episode: 98 Total reward: 52.0 Training loss: 7.7319 Explore P: 0.6456
# Episode: 99 Total reward: 95.0 Training loss: 9.6278 Explore P: 0.6452
# Episode: 100 Total reward: 92.0 Training loss: 7.1014 Explore P: 0.6446
# Model Saved
# Episode: 101 Total reward: 73.0 Training loss: 9.9466 Explore P: 0.6431
# Episode: 102 Total reward: 32.0 Training loss: 8.8187 Explore P: 0.6397
# Episode: 103 Total reward: 95.0 Training loss: 37.8659 Explore P: 0.6394
# Episode: 104 Total reward: 21.0 Training loss: 9.6562 Explore P: 0.6353
# Episode: 105 Total reward: 72.0 Training loss: 7.9976 Explore P: 0.6338
# Model Saved
# Episode: 106 Total reward: 70.0 Training loss: 14.9645 Explore P: 0.6322
# Episode: 107 Total reward: 27.0 Training loss: 12.7850 Explore P: 0.6285
# Episode: 108 Total reward: 65.0 Training loss: 7.5877 Explore P: 0.6266
# Episode: 110 Total reward: 6.0 Training loss: 14.0660 Explore P: 0.6156
# Model Saved
# Episode: 111 Total reward: 15.0 Training loss: 10.7258 Explore P: 0.6113
# Episode: 112 Total reward: 48.0 Training loss: 5.6708 Explore P: 0.6087
# Episode: 113 Total reward: 91.0 Training loss: 14.3668 Explore P: 0.6081
# Episode: 114 Total reward: 70.0 Training loss: 18.4810 Explore P: 0.6066
# Model Saved
# Episode: 116 Total reward: 36.0 Training loss: 7.1335 Explore P: 0.5974
# Episode: 118 Total reward: 95.0 Training loss: 7.7091 Explore P: 0.5912
# Episode: 120 Total reward: 95.0 Training loss: 38.4877 Explore P: 0.5851
# Model Saved
# Episode: 121 Total reward: 95.0 Training loss: 8.0984 Explore P: 0.5847
# Episode: 122 Total reward: 95.0 Training loss: 20.5675 Explore P: 0.5844
# Episode: 123 Total reward: 94.0 Training loss: 7.3633 Explore P: 0.5840
# Episode: 124 Total reward: 94.0 Training loss: 5.3782 Explore P: 0.5836
# Episode: 125 Total reward: 51.0 Training loss: 8.7888 Explore P: 0.5813
# Model Saved
# Episode: 126 Total reward: 95.0 Training loss: 11.0394 Explore P: 0.5810
# Episode: 127 Total reward: 26.0 Training loss: 7.8898 Explore P: 0.5775
# Episode: 128 Total reward: 95.0 Training loss: 12.1947 Explore P: 0.5772
# Episode: 129 Total reward: 9.0 Training loss: 13.0180 Explore P: 0.5728
# Episode: 130 Total reward: 12.0 Training loss: 10.1878 Explore P: 0.5687
# Model Saved
# Episode: 131 Total reward: 72.0 Training loss: 6.5741 Explore P: 0.5674
# Episode: 132 Total reward: -11.0 Training loss: 10.2285 Explore P: 0.5623
# Episode: 134 Total reward: 95.0 Training loss: 11.7529 Explore P: 0.5564
# Episode: 135 Total reward: 93.0 Training loss: 14.6612 Explore P: 0.5560
# Model Saved
# Episode: 136 Total reward: 95.0 Training loss: 12.4122 Explore P: 0.5557
# Episode: 137 Total reward: 52.0 Training loss: 9.4955 Explore P: 0.5535
# Episode: 138 Total reward: 95.0 Training loss: 6.5675 Explore P: 0.5532
# Episode: 139 Total reward: 44.0 Training loss: 5.6437 Explore P: 0.5507
# Episode: 140 Total reward: 49.0 Training loss: 18.1434 Explore P: 0.5484
# Model Saved
# Episode: 141 Total reward: 33.0 Training loss: 15.3573 Explore P: 0.5453
# Episode: 142 Total reward: 94.0 Training loss: 29.4363 Explore P: 0.5449
# Episode: 143 Total reward: 89.0 Training loss: 10.4101 Explore P: 0.5443
# Episode: 144 Total reward: 95.0 Training loss: 10.1641 Explore P: 0.5440
# Episode: 145 Total reward: 24.0 Training loss: 6.2977 Explore P: 0.5407
# Model Saved
# Episode: 146 Total reward: 70.0 Training loss: 18.4426 Explore P: 0.5393
# Episode: 147 Total reward: 63.0 Training loss: 21.9404 Explore P: 0.5375
# Episode: 148 Total reward: 88.0 Training loss: 4.3560 Explore P: 0.5368
# Episode: 149 Total reward: 54.0 Training loss: 34.9261 Explore P: 0.5346
# Episode: 150 Total reward: 65.0 Training loss: 10.0098 Explore P: 0.5330
# Model Saved
# Episode: 151 Total reward: 67.0 Training loss: 10.7395 Explore P: 0.5315
# Episode: 153 Total reward: -16.0 Training loss: 10.2018 Explore P: 0.5216
# Episode: 155 Total reward: 7.0 Training loss: 7.1911 Explore P: 0.5125
# Model Saved
# Episode: 156 Total reward: 43.0 Training loss: 11.9937 Explore P: 0.5101
# Episode: 157 Total reward: 94.0 Training loss: 11.8343 Explore P: 0.5097
# Episode: 158 Total reward: 18.0 Training loss: 8.0080 Explore P: 0.5064
# Episode: 159 Total reward: 44.0 Training loss: 12.7609 Explore P: 0.5040
# Episode: 160 Total reward: 95.0 Training loss: 12.2151 Explore P: 0.5037
# Model Saved
# Episode: 161 Total reward: 63.0 Training loss: 6.9979 Explore P: 0.5021
# Episode: 162 Total reward: 85.0 Training loss: 19.6373 Explore P: 0.5013
# Episode: 163 Total reward: 48.0 Training loss: 10.6015 Explore P: 0.4992
# Episode: 164 Total reward: 93.0 Training loss: 13.2506 Explore P: 0.4988
# Episode: 165 Total reward: 16.0 Training loss: 17.6225 Explore P: 0.4954
# Model Saved
# Episode: 166 Total reward: 74.0 Training loss: 13.5059 Explore P: 0.4943
# Episode: 167 Total reward: 95.0 Training loss: 23.1468 Explore P: 0.4941
# Episode: 168 Total reward: 76.0 Training loss: 13.6342 Explore P: 0.4931
# Episode: 169 Total reward: 44.0 Training loss: 12.8790 Explore P: 0.4908
# Episode: 170 Total reward: 95.0 Training loss: 13.4885 Explore P: 0.4905
# Model Saved
# Episode: 171 Total reward: 94.0 Training loss: 24.8450 Explore P: 0.4902
# Episode: 172 Total reward: 95.0 Training loss: 11.5581 Explore P: 0.4899
# Episode: 173 Total reward: 93.0 Training loss: 13.2323 Explore P: 0.4895
# Episode: 174 Total reward: 95.0 Training loss: 35.7054 Explore P: 0.4892
# Episode: 175 Total reward: 94.0 Training loss: 14.0734 Explore P: 0.4889
# Model Saved
# Episode: 176 Total reward: 95.0 Training loss: 17.7638 Explore P: 0.4886
# Episode: 177 Total reward: 70.0 Training loss: 9.5250 Explore P: 0.4874
# Episode: 178 Total reward: 76.0 Training loss: 17.4495 Explore P: 0.4864
# Episode: 179 Total reward: 95.0 Training loss: 12.1829 Explore P: 0.4861
# Episode: 180 Total reward: 66.0 Training loss: 19.4910 Explore P: 0.4847
# Model Saved
# Episode: 181 Total reward: 95.0 Training loss: 13.0018 Explore P: 0.4844
# Episode: 182 Total reward: 24.0 Training loss: 6.9294 Explore P: 0.4815
# Episode: 183 Total reward: 75.0 Training loss: 5.3705 Explore P: 0.4805
# Episode: 184 Total reward: 92.0 Training loss: 7.6999 Explore P: 0.4801
# Episode: 185 Total reward: 43.0 Training loss: 13.7024 Explore P: 0.4776
# Model Saved
# Episode: 186 Total reward: 52.0 Training loss: 10.8936 Explore P: 0.4755
# Episode: 187 Total reward: 21.0 Training loss: 5.3448 Explore P: 0.4725
# Episode: 188 Total reward: 93.0 Training loss: 9.5945 Explore P: 0.4722
# Episode: 189 Total reward: 95.0 Training loss: 34.0118 Explore P: 0.4719
# Episode: 190 Total reward: 66.0 Training loss: 6.0605 Explore P: 0.4705
# Model Saved
# Episode: 191 Total reward: 95.0 Training loss: 13.0699 Explore P: 0.4702
# Episode: 192 Total reward: 95.0 Training loss: 24.5482 Explore P: 0.4699
# Episode: 193 Total reward: 95.0 Training loss: 8.9502 Explore P: 0.4697
# Episode: 194 Total reward: 95.0 Training loss: 11.3662 Explore P: 0.4694
# Episode: 195 Total reward: 50.0 Training loss: 10.3623 Explore P: 0.4675
# Model Saved
# Episode: 196 Total reward: 94.0 Training loss: 6.4600 Explore P: 0.4672
# Episode: 198 Total reward: 95.0 Training loss: 8.2108 Explore P: 0.4624
# Episode: 199 Total reward: 22.0 Training loss: 16.7341 Explore P: 0.4595
# Episode: 200 Total reward: 75.0 Training loss: 18.1081 Explore P: 0.4585
# Model Saved
# Episode: 201 Total reward: 95.0 Training loss: 9.8341 Explore P: 0.4583
# Episode: 202 Total reward: 90.0 Training loss: 7.6393 Explore P: 0.4578
# Episode: 203 Total reward: 93.0 Training loss: 19.7991 Explore P: 0.4574
# Episode: 204 Total reward: 68.0 Training loss: 7.5840 Explore P: 0.4562
# Episode: 205 Total reward: 71.0 Training loss: 7.3687 Explore P: 0.4551
# Model Saved
# Episode: 206 Total reward: 75.0 Training loss: 18.5004 Explore P: 0.4541
# Episode: 207 Total reward: 43.0 Training loss: 11.5267 Explore P: 0.4520
# Episode: 208 Total reward: 69.0 Training loss: 10.0627 Explore P: 0.4508
# Episode: 209 Total reward: 73.0 Training loss: 21.9055 Explore P: 0.4498
# Episode: 210 Total reward: 95.0 Training loss: 12.8760 Explore P: 0.4495
# Model Saved
# Episode: 211 Total reward: 94.0 Training loss: 14.5215 Explore P: 0.4492
# Episode: 212 Total reward: 93.0 Training loss: 10.4622 Explore P: 0.4489
# Episode: 213 Total reward: 60.0 Training loss: 7.1596 Explore P: 0.4473
# Episode: 214 Total reward: 10.0 Training loss: 13.0004 Explore P: 0.4440
# Episode: 215 Total reward: 93.0 Training loss: 9.9730 Explore P: 0.4436
# Model Saved
# Episode: 216 Total reward: 91.0 Training loss: 16.9120 Explore P: 0.4432
# Episode: 217 Total reward: 29.0 Training loss: 9.7050 Explore P: 0.4405
# Episode: 218 Total reward: 95.0 Training loss: 7.6350 Explore P: 0.4403
# Episode: 219 Total reward: 95.0 Training loss: 9.2718 Explore P: 0.4400
# Episode: 220 Total reward: 95.0 Training loss: 19.1250 Explore P: 0.4398
# Model Saved
# Episode: 221 Total reward: 94.0 Training loss: 9.2612 Explore P: 0.4394
# Episode: 222 Total reward: 40.0 Training loss: 29.3278 Explore P: 0.4373
# Episode: 223 Total reward: 73.0 Training loss: 15.0071 Explore P: 0.4363
# Episode: 224 Total reward: 92.0 Training loss: 6.1675 Explore P: 0.4359
# Episode: 225 Total reward: 94.0 Training loss: 12.3312 Explore P: 0.4356
# Model Saved
# Episode: 226 Total reward: 51.0 Training loss: 9.2206 Explore P: 0.4337
# Episode: 227 Total reward: 94.0 Training loss: 13.3893 Explore P: 0.4334
# Episode: 228 Total reward: 66.0 Training loss: 9.7461 Explore P: 0.4321
# Episode: 229 Total reward: 53.0 Training loss: 9.5943 Explore P: 0.4303
# Episode: 230 Total reward: 95.0 Training loss: 13.7858 Explore P: 0.4301
# Model Saved
# Episode: 231 Total reward: 55.0 Training loss: 18.5988 Explore P: 0.4283
# Episode: 232 Total reward: 94.0 Training loss: 13.4559 Explore P: 0.4281
# Episode: 233 Total reward: 95.0 Training loss: 21.6603 Explore P: 0.4278
# Episode: 234 Total reward: 94.0 Training loss: 12.8170 Explore P: 0.4275
# Episode: 235 Total reward: 46.0 Training loss: 5.2885 Explore P: 0.4256
# Model Saved
# Episode: 236 Total reward: 39.0 Training loss: 12.7470 Explore P: 0.4235
# Episode: 237 Total reward: 50.0 Training loss: 38.6342 Explore P: 0.4218
# Episode: 238 Total reward: 92.0 Training loss: 6.6973 Explore P: 0.4214
# Episode: 239 Total reward: 52.0 Training loss: 13.8439 Explore P: 0.4198
# Episode: 240 Total reward: 91.0 Training loss: 9.5396 Explore P: 0.4194
# Model Saved
# Episode: 241 Total reward: 89.0 Training loss: 8.8593 Explore P: 0.4189
# Episode: 242 Total reward: 95.0 Training loss: 12.6920 Explore P: 0.4187
# Episode: 243 Total reward: 48.0 Training loss: 19.3575 Explore P: 0.4169
# Episode: 244 Total reward: 52.0 Training loss: 7.7311 Explore P: 0.4151
# Episode: 245 Total reward: 42.0 Training loss: 10.5857 Explore P: 0.4131
# Model Saved
# Episode: 246 Total reward: 64.0 Training loss: 30.4655 Explore P: 0.4119
# Episode: 247 Total reward: 95.0 Training loss: 23.4294 Explore P: 0.4116
# Episode: 248 Total reward: 94.0 Training loss: 10.0872 Explore P: 0.4113
# Episode: 249 Total reward: 38.0 Training loss: 14.8806 Explore P: 0.4092
# Episode: 250 Total reward: 7.0 Training loss: 11.2054 Explore P: 0.4061
# Model Saved
# Episode: 251 Total reward: 94.0 Training loss: 11.4799 Explore P: 0.4058
# Episode: 252 Total reward: 92.0 Training loss: 17.3167 Explore P: 0.4054
# Episode: 253 Total reward: 64.0 Training loss: 9.5099 Explore P: 0.4042
# Episode: 254 Total reward: 64.0 Training loss: 7.4256 Explore P: 0.4029
# Episode: 255 Total reward: 95.0 Training loss: 7.1778 Explore P: 0.4027
# Model Saved
# Episode: 257 Total reward: 95.0 Training loss: 13.6300 Explore P: 0.3985
# Episode: 258 Total reward: 95.0 Training loss: 9.2125 Explore P: 0.3983
# Episode: 259 Total reward: 46.0 Training loss: 14.2816 Explore P: 0.3966
# Episode: 260 Total reward: 90.0 Training loss: 9.7435 Explore P: 0.3961
# Model Saved
# Episode: 261 Total reward: 85.0 Training loss: 8.8558 Explore P: 0.3955
# Episode: 262 Total reward: 95.0 Training loss: 17.5665 Explore P: 0.3953
# Episode: 263 Total reward: 95.0 Training loss: 6.8337 Explore P: 0.3951
# Episode: 264 Total reward: 95.0 Training loss: 12.4404 Explore P: 0.3948
# Episode: 265 Total reward: 95.0 Training loss: 11.3435 Explore P: 0.3946
# Model Saved
# Episode: 266 Total reward: 94.0 Training loss: 60.6475 Explore P: 0.3943
# Episode: 267 Total reward: 65.0 Training loss: 12.7986 Explore P: 0.3931
# Episode: 268 Total reward: 95.0 Training loss: 9.1067 Explore P: 0.3929
# Episode: 269 Total reward: 36.0 Training loss: 17.0473 Explore P: 0.3908
# Episode: 270 Total reward: 92.0 Training loss: 13.9732 Explore P: 0.3905
# Model Saved
# Episode: 271 Total reward: 94.0 Training loss: 8.3621 Explore P: 0.3902
# Episode: 272 Total reward: 53.0 Training loss: 13.9409 Explore P: 0.3888
# Episode: 273 Total reward: 92.0 Training loss: 20.8012 Explore P: 0.3884
# Episode: 275 Total reward: 94.0 Training loss: 13.2004 Explore P: 0.3844
# Model Saved
# Episode: 276 Total reward: 57.0 Training loss: 18.0780 Explore P: 0.3831
# Episode: 277 Total reward: 94.0 Training loss: 10.9315 Explore P: 0.3829
# Episode: 278 Total reward: 43.0 Training loss: 16.6396 Explore P: 0.3811
# Episode: 279 Total reward: 94.0 Training loss: 17.1305 Explore P: 0.3808
# Episode: 280 Total reward: 91.0 Training loss: 11.2066 Explore P: 0.3804
# Model Saved
# Episode: 281 Total reward: 47.0 Training loss: 9.0012 Explore P: 0.3788
# Episode: 282 Total reward: 66.0 Training loss: 13.7453 Explore P: 0.3777
# Episode: 283 Total reward: 94.0 Training loss: 6.9572 Explore P: 0.3775
# Episode: 284 Total reward: 94.0 Training loss: 11.1755 Explore P: 0.3772
# Episode: 285 Total reward: 69.0 Training loss: 10.5733 Explore P: 0.3762
# Model Saved
# Episode: 286 Total reward: 94.0 Training loss: 11.0985 Explore P: 0.3760
# Episode: 287 Total reward: 94.0 Training loss: 11.6506 Explore P: 0.3757
# Episode: 288 Total reward: 62.0 Training loss: 8.6537 Explore P: 0.3745
# Episode: 289 Total reward: 91.0 Training loss: 10.4808 Explore P: 0.3741
# Episode: 290 Total reward: 95.0 Training loss: 4.4722 Explore P: 0.3739
# Model Saved
# Episode: 291 Total reward: 95.0 Training loss: 10.3423 Explore P: 0.3737
# Episode: 292 Total reward: 92.0 Training loss: 12.3901 Explore P: 0.3733
# Episode: 293 Total reward: 94.0 Training loss: 9.5460 Explore P: 0.3731
# Episode: 294 Total reward: 95.0 Training loss: 7.8798 Explore P: 0.3729
# Model Saved
# Episode: 296 Total reward: 92.0 Training loss: 6.9918 Explore P: 0.3689
# Episode: 297 Total reward: 95.0 Training loss: 15.7006 Explore P: 0.3687
# Episode: 298 Total reward: 95.0 Training loss: 13.8754 Explore P: 0.3685
# Episode: 299 Total reward: 95.0 Training loss: 9.2604 Explore P: 0.3683

# %% [markdown]
# ## Step 9: Watch our Agent play 👀
# Now that we trained our agent, we can test it

# %%
with tf.compat.v1.Session() as sess:

    game, possible_actions = create_environment()

    totalScore = 0

    # Load the model
    saver.restore(sess, "./models/model.ckpt")
    game.init()
    for i in range(1):

        done = False

        game.new_episode()

        state = game.get_state().screen_buffer
        state, stacked_frames = stack_frames(stacked_frames, state, True)

        while not game.is_episode_finished():
            # Take the biggest Q value (= the best action)
            Qs = sess.run(DQNetwork.output, feed_dict = {DQNetwork.inputs_: state.reshape((1, *state.shape))})

            # Take the biggest Q value (= the best action)
            choice = np.argmax(Qs)
            action = possible_actions[int(choice)]

            game.make_action(action)
            done = game.is_episode_finished()
            score = game.get_total_reward()

            if done:
                break

            else:
                print("else")
                next_state = game.get_state().screen_buffer
                next_state, stacked_frames = stack_frames(stacked_frames, next_state, False)
                state = next_state

        score = game.get_total_reward()
        print("Score: ", score)
    game.close()
# Out:
# INFO:tensorflow:Restoring parameters from ./models/model.ckpt
# else
# else
# else
# else
# else
# else
# else
# else
# Score:  92.0
